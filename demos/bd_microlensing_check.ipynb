# %% [markdown]
# ## Brown Dwarf Microlensing Event Checker:
#
# We are using 3 catalogs for the objects: Kirkpatrick21 (K21), Best20 (B20), and the Ultracool Sheet (UCS). In the event that a particular object is in multiple catalogs, we use the astrometry from the newer source (K21 > B20 > UCS).

# %% [markdown]
# #### Imports:

# %%
# add path to module so can import mlfinder code
import sys
sys.path = ['/Users/judahluberto/mlfinder'] + sys.path

# ignore future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# basic imports
from astropy.io import ascii
from astropy.table import Table
from astropy.time import Time
from astropy.coordinates import SkyCoord
import astropy.units as u

import math

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

import statistics

from PyAstronomy import pyasl

import os

# datalab imports for background stars
import dl
from dl import queryClient as qc
from dl.helpers.utils import convert

# import mlfinder module
from mlfinder.bd import BrownDwarf
from mlfinder.fields import Fields
from mlfinder.events import FindEvents
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# #### Let's grab the objects from files we've downloaded from the papers:

# %%
file_path = '/Users/judahluberto/python/'

# %% [markdown]
# Starting with K21:

# %%
# grab files
high_qual_bd = pd.DataFrame(np.array(ascii.read(file_path + 'datafile5.txt')))
low_qual_bd = pd.DataFrame(np.array(ascii.read(file_path + 'datafile6.txt')))

# changing some of their column names for uniformity
rename_dict_k21 = {'FName':'object_name', 
               'RAdeg':'ra', 
               'DEdeg':'dec',
               't0': 't0',
               'plx':'pi', 
               'pmRA':'mu_alpha', 
               'pmDE':'mu_delta', 
               'e_RAdeg':'pm_ra',
               'e_DEdeg':'pm_dec',
               'e_pmRA':'pm_mu_alpha',
               'e_pmDE':'pm_mu_delta',
               'e_plx': 'pm_pi'}


high_qual_bd = high_qual_bd.rename(columns = rename_dict_k21)
low_qual_bd = low_qual_bd.rename(columns = rename_dict_k21)

# now keep those columns too -- for simplicity!
keep_list_k21 = ['object_name', 'ra', 'dec', 't0', 'pi', 'mu_alpha', 'mu_delta', 'pm_ra', 'pm_dec', 'pm_mu_alpha', 'pm_mu_delta', 'pm_pi']

high_qual_bd = high_qual_bd[keep_list_k21]
low_qual_bd = low_qual_bd[keep_list_k21]

# combine the two for simplicity
k21_obj = high_qual_bd.append(low_qual_bd, ignore_index=True)

# convert error in ra and dec from milliarcseconds to degrees
conversion = (3600 * 1000) # number of milliarcseconds in a degree

k21_obj.pm_ra /= conversion
k21_obj.pm_dec /= conversion

# %% [markdown]
# Now for B20:

# %%
# file
b20_obj = pd.DataFrame(np.array(ascii.read(file_path + 'ajab84f4t4_mrt.txt')))

# rename
rename_dict_b20 = {'Object':'object_name', 
               'RAdeg':'ra', 
               'DEdeg':'dec', 
               'Epoch': 't0',
               'omega-rel':'pi', 
               'pmRA-rel':'mu_alpha', 
               'pmDE-rel':'mu_delta', 
               'e_pmRA-rel':'pm_mu_alpha',
               'e_pmDE-rel':'pm_mu_delta',
               'e_omega-rel': 'pm_pi'}


b20_obj = b20_obj.rename(columns = rename_dict_b20)

# add ra and dec error columns with 0 bc B20 didnt have positional uncertainty
b20_obj['pm_ra'] = 0
b20_obj['pm_dec'] = 0

# keep columns
keep_list_b20 = ['object_name', 'ra', 'dec', 't0', 'pi', 'mu_alpha', 'mu_delta', 'pm_ra', 'pm_dec', 'pm_mu_alpha', 'pm_mu_delta', 'pm_pi']

b20_obj = b20_obj[keep_list_b20]

# convert error in ra and dec from milliarcseconds to degrees
conversion = (3600 * 1000) # number of milliarcseconds in a degree

b20_obj.pm_ra /= conversion
b20_obj.pm_dec /= conversion

# %% [markdown]
# For UCS:
#
# - Note that not filtering any non-exoplanet objects, and are entrusting the authors of UCS in the selection of the objects

# %%
# file
ultracool_file = '/Users/judahluberto/Downloads/UltracoolSheet - Main.csv'

ucs_obj = pd.read_csv(ultracool_file)

# rename
rename_dict_ucs = {'name':'object_name', 
               'ra_today_formula':'ra', 
               'dec_today_formula':'dec',
               'plx_formula':'pi', 
               'pmra_formula':'mu_alpha', 
               'pmdec_formula':'mu_delta',
               'plxerr_formula': 'pm_pi',
               'pmraerr_formula': 'pm_mu_alpha',
               'pmdecerr_formula': 'pm_mu_delta',}

ucs_obj = ucs_obj.rename(columns = rename_dict_ucs)

# remove objects that they define as exoplanets or subdwarfs
ucs_obj = ucs_obj[~ucs_obj.exoplanet.str.contains('Y', na=False)]

# remove objects that have no parallax
ucs_obj = ucs_obj[ucs_obj.pi > 0]

# make copy of table for later
ucs_obj_all = ucs_obj.copy()

# keep list
keep_list_ucs = ['object_name', 'ra', 'dec', 'pi', 'mu_alpha', 'mu_delta', 'pm_mu_alpha', 'pm_mu_delta', 'pm_pi']

ucs_obj = ucs_obj[keep_list_ucs]

# add ra and dec err of 0 (objects listed do not have errors)
ucs_obj['pm_ra'] = 0
ucs_obj['pm_dec'] = 0

# convert J2000 to ICRS (which is what the legacy survey, our background star source, uses). are close but might as well
ucs_coord = SkyCoord(ucs_obj.ra, ucs_obj.dec, unit='deg', frame='fk5')
ucs_coord = ucs_coord.transform_to('icrs')

ucs_new_ra = ucs_coord.ra.deg
ucs_new_dec = ucs_coord.dec.deg

ucs_obj['ra'] = ucs_new_ra
ucs_obj['dec'] = ucs_new_dec

# add column of t0 to array with 2020-11-01 as the observe date based on the README and the today formulas in UCS
mjds = np.full((1, len(ucs_obj)), 59154)[0]
ucs_obj['t0'] = mjds

# %% [markdown]
# Now to combine the catalogs, add a columns showing the reference astrometry, and a column of the date of the data depending on the astrometry:

# %%
# combine
all_obj = k21_obj.append([b20_obj, ucs_obj], ignore_index=True).drop_duplicates(subset='object_name')

# drop objects without parallax and 

all_names = all_obj['object_name']
davy_names = list(k21_obj['object_name'])
best_names = list(b20_obj['object_name'])
ultracool_names = list(ucs_obj['object_name'])

refs = list()
for index, value in enumerate(all_names):
    # add to refs list
    if value in davy_names:
        refs.append('K21')
        
    elif value in best_names:
        refs.append('B20')
        
    elif value in ultracool_names:
        refs.append('UCS')
    
# add column to dataframe
all_obj['Ref'] = refs

# %%
all_obj[all_obj.object_name == 'WISE J083337.83+005214.2']
# Out:
#                   object_name          ra       dec        t0    pi  mu_alpha  \
# 107  WISE J083337.83+005214.2  128.409249  0.867492  57937.66  79.7     786.8
#
#      mu_delta         pm_ra        pm_dec  pm_mu_alpha  pm_mu_delta  pm_pi  \
# 107   -1593.7  7.777778e-07  7.777778e-07          2.1          2.0    3.1
#
#      Ref
# 107  K21

# %% [markdown]
# #### Run the mlfinder code to see if there are any events:
#
# - Maximum "event" mass uncertainty to 1000 Mjup
# - Start and end date at 2014 - 2032. 2014 to catch any events that might've been seen with Gaia, 2032 to look 10 years in future. Any further and we will have telescopes with far better capabilities

# %% [markdown]
# We will need to convert dates to proper form, so let's make a function to do that for us first:
# - Of course using the clever name "time_to_good" which reformats our time to a good one :)
# - init_format is the intial format of the time. Is MJD for object input, but with the MC, it is decimalyear

# %%
month_dict = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'}

def time_to_good(date, init_format='mjd'):
    # create Time instantiation to turn from MJD to iso
    t = Time(float(date), format=init_format)
    t.format = 'iso'
    t = t.value
    
    # split into month, day, year
    t_split = t.split()[0]
    t_split = t_split.split('-')

    # final reformat
    t = t_split[0] + '-' + str(month_dict[int(t_split[1])]) + '-' + t_split[2]
    
    return t

# %%
# initliaze a dataframe to append events to, and mc dict of mass uncertainties if done
all_events = pd.DataFrame()
for index, row in all_obj.iterrows():
    # print to keep us updated
    print('Working on dwarf {}, index {}...'.format(row.object_name, index))

    # turn row into a pandas dataframe for ease
    row = row.to_frame().T

    # get time in good format
    t = time_to_good(row.t0)

    # create brown dwarf class and find a future path
    bd = BrownDwarf(row, observ_date=t)
    bd_path = bd.find_path(start='2014-Jan-01', end='2032-Jan-01', step='7days')

    # find the background stars from the Legacy Survey
    stars = Fields(bd=bd)

    # find events with mass uncertainty lower than 1000 Mjup
    events = FindEvents(bd, stars, 1000)

    # append to dataframe
    all_events = all_events.append(events.event_table)
# Out:
# Working on dwarf WISE J000517.48+373720.5, index 0...
# Working on dwarf WISE J001505.87-461517.6, index 1...
# Working on dwarf PSO J007.9194+33.5961, index 2...
# Working on dwarf WISE J003110.04+574936.3, index 3...
# Working on dwarf WISE J003231.09-494651.4, index 4...
# Working on dwarf 2MASS J00345157+0523050, index 5...
# Working on dwarf WISE J003829.05+275852.1, index 6...
# Working on dwarf CWISE J004143.77-401929.9, index 7...
# Working on dwarf WISE J004542.56+361139.1, index 8...
# Working on dwarf WISE J004945.61+215120.0, index 9...
# Working on dwarf WISEA J005811.69-565332.1, index 10...
# Working on dwarf CWISEP J010527.69-783419.3, index 11...
# Working on dwarf WISE J011154.36-505343.2, index 12...
# Working on dwarf WISEPA J012333.21+414203.9, index 13...
# Working on dwarf CFBDS J013302.27+023128.4, index 14...
# Working on dwarf WISE J014656.66+423410.0, index 15...
# Working on dwarf WISEP J015010.86+382724.3, index 16...
# Working on dwarf 2MASS J01550354+0950003, index 17...
# Working on dwarf WISEA J020047.29-510521.4, index 18...
# Working on dwarf 2MASSW J0205034+125142, index 19...
# Working on dwarf WISEP J022105.94+384202.9, index 20...
# Working on dwarf WISEPA J022623.98-021142.8, index 21...
# Working on dwarf WISE J023318.05+303030.5, index 22...
# Working on dwarf WISE J024124.73-365328.0, index 23...
# Working on dwarf WISE J024512.62-345047.8, index 24...
# Working on dwarf WISE J024714.52+372523.5, index 25...
# Working on dwarf WISEA J030237.53-581740.3, index 26...
# Working on dwarf WISE J030449.03-270508.3, index 27...
# Working on dwarf WISEA J030919.70-501614.2, index 28...
# Working on dwarf WISEPA J031325.96+780744.2, index 29...
# Working on dwarf WISE J031614.68+382008.0, index 30...
# Working on dwarf WISE J031624.35+430709.1, index 31...
# Working on dwarf 2MASS J03185403-3421292, index 32...
# Working on dwarf CWISEP J032109.59+693204.5, index 33...
# Working on dwarf WISE J032301.86+562558.0, index 34...
# Working on dwarf WISEA J032309.12- 590751.0, index 35...
# Working on dwarf WISEPC J032337.53-602554.9, index 36...
# Working on dwarf WISE J032517.69-385454.1, index 37...
# Working on dwarf WISE J032504.33-504400.3, index 38...
# Working on dwarf WISE J032547.72+083118.2, index 39...
# Working on dwarf SDSSp J033035.13-002534.5, index 40...
# Working on dwarf PSO J052.7214-03.8409, index 41...
# Working on dwarf WISEPC J033349.34-585618.7, index 42...
# Working on dwarf WISE J033515.01+431045.1, index 43...
# Working on dwarf WISE J033605.05-014350.4, index 44...
# Working on dwarf WISE J033651.90+282628.8, index 45...
# Working on dwarf 2MASSW J0337036-175807, index 46...
# Working on dwarf 2MASS J03400942-6724051, index 47...
# Working on dwarf WISE J035000.32-565830.2, index 48...
# Working on dwarf UGPS J03553200+4743588, index 49...
# Working on dwarf 2MASS J03582255-4116060, index 50...
# Working on dwarf WISE J035934.06-540154.6, index 51...
# Working on dwarf WISE J040443.48-642029.9, index 52...
# Working on dwarf WISEPA J041022.71+150248.5, index 53...
# Working on dwarf WISE J041358.14-475039.3, index 54...
# Working on dwarf 2MASS J04210718-6306022, index 55...
# Working on dwarf WISE J043052.92+463331.6, index 56...
# Working on dwarf 2MASSI J0443058-320209, index 57...
# Working on dwarf WISEPA J044853.29-193548.5, index 58...
# Working on dwarf WISE J045746.08-020719.2, index 59...
# Working on dwarf WISEPA J045853.89+643452.9, index 60...
# Working on dwarf WISEPA J050003.05-122343.2, index 61...
# Working on dwarf WISEA J050238.28+100750.0, index 62...
# Working on dwarf WISEU J050305.68-564834.0, index 63...
# Working on dwarf PSO J076.7092+52.6087, index 64...
# Working on dwarf 2MASSI J0512063-294954, index 65...
# Working on dwarf WISE J051208.66-300404.4, index 66...
# Working on dwarf WISE J052126.29+102528.4, index 67...
# Working on dwarf WISE J053516.80-750024.9, index 68...
# Working on dwarf CWISEP J053644.82-305539.3, index 69...
# Working on dwarf CWISE J054025.89-180240.3, index 70...
# Working on dwarf WISE J054047.00+483232.4, index 71...
# Working on dwarf WISE J054601.19-095947.5, index 72...
# Working on dwarf 2MASS J06020638+4043588, index 73...
# Working on dwarf CWISE J061348.70+480820.5, index 74...
# Working on dwarf WISE J061437.73+095135.0, index 75...
# Working on dwarf WISEA J061557.21+152626.1, index 76...
# Working on dwarf WISE J062842.71-805725.0, index 77...
# Working on dwarf WISE J062905.13+241804.9, index 78...
# Working on dwarf CWISEP J063428.10+504925.9, index 79...
# Working on dwarf WISE J064205.58+410155.5, index 80...
# Working on dwarf WISEA J064503.72+524054.1, index 81...
# Working on dwarf WISEA J064528.39-030247.9, index 82...
# Working on dwarf 2MASS J06453153-6646120, index 83...
# Working on dwarf WISE J064723.23-623235.5, index 84...
# Working on dwarf WISEA J064750.85-154616.4, index 85...
# Working on dwarf PSO J103.0927+41.4601, index 86...
# Working on dwarf WISE J070159.79+632129.2, index 87...
# Working on dwarf WISEA J071301.86-585445.2, index 88...
# Working on dwarf WISE J071322.55-291751.9, index 89...
# Working on dwarf WISE J072312.44+340313.5, index 90...
# Working on dwarf WISE J073444.02-715744.0, index 91...
# Working on dwarf 2MASS J07414279-0506464, index 92...
# Working on dwarf SDSS J074149.15+235127.5, index 93...
# Working on dwarf SDSS J074201.41+205520.5, index 94...
# Working on dwarf WISEPA J074457.15+562821.8, index 95...
# Working on dwarf 2MASS J07555430-3259589, index 96...
# Working on dwarf 2MASSI J0755480+221218, index 97...
# Working on dwarf SDSS J075840.33+324723.4, index 98...
# Working on dwarf WISEPC J075946.98-490454.0, index 99...
# Working on dwarf WISEA J080622.22-082046.5, index 100...
# Working on dwarf WISE J080700.23+413026.8, index 101...
# Working on dwarf SDSS J080959.01+443422.2, index 102...
# Working on dwarf WISE J081220.04+402106.2, index 103...
# Working on dwarf WISE J082000.48-662211.9, index 104...
# Working on dwarf WISE J082507.35+280548.5, index 105...
# Working on dwarf WISEA J082640.45-164031.8, index 106...
# Working on dwarf WISE J083337.83+005214.2, index 107...
# Working on dwarf WISEPC J083641.12-185947.2, index 108...
# Working on dwarf SDSS J085234.90+472035.0, index 109...
# Working on dwarf WISE J085510.83-071442.5, index 110...
# Working on dwarf WISEPA J085716.25+560407.6, index 111...
# Working on dwarf SDSSp J085758.45+570851.4, index 112...
# Working on dwarf SDSS J085834.42+325627.7, index 113...
# Working on dwarf 2MASS J09054654+5623117, index 114...
# Working on dwarf WISEPA J090649.36+473538.6, index 115...
# Working on dwarf SDSS J090900.73+652527.2, index 116...
# Working on dwarf WISE J091408.96-345941.5, index 117...
# Working on dwarf WISE J092055.40+453856.3, index 118...
# Working on dwarf WISEA J094020.09-220820.5, index 119...
# Working on dwarf WISE J094305.98+360723.5, index 120...
# Working on dwarf WISEPC J095259.29+195507.3, index 121...
# Working on dwarf PSO J149.0341-14.7857, index 122...
# Working on dwarf 2MASSI J1010148-040649, index 123...
# Working on dwarf ULAS J101243.54+102101.7, index 124...
# Working on dwarf WISEPC J101808.05-244557.7, index 125...
# Working on dwarf WISE J102557.72+030755.7, index 126...
# Working on dwarf CFBDS J102841.01+565401.9, index 127...
# Working on dwarf 2MASSW J1036530-344138, index 128...
# Working on dwarf WISE J103907.73-160002.9, index 129...
# Working on dwarf 2MASS J10430758+2225236, index 130...
# Working on dwarf SDSS J104335.08+121314.1, index 131...
# Working on dwarf WISE J105047.90+505606.2, index 132...
# Working on dwarf WISE J105130.01-213859.7, index 133...
# Working on dwarf WISE J105257.95-194250.2, index 134...
# Working on dwarf WISEA J105553.62-165216.5, index 135...
# Working on dwarf CWISE J105512.11+544328.3, index 136...
# Working on dwarf 2MASSI J1104012+195921, index 137...
# Working on dwarf WISE J111239.24-385700.7, index 138...
# Working on dwarf WISE J112438.12-042149.7, index 139...
# Working on dwarf SIMP J11322058-3809562, index 140...
# Working on dwarf CWISE J113717.27-532007.9, index 141...
# Working on dwarf WISE J113949.24-332425.1, index 142...
# Working on dwarf WISEA J114156.67-332635.5, index 143...
# Working on dwarf WISE J114340.22+443123.8, index 144...
# Working on dwarf WISEP J115013.88+630240.7, index 145...
# Working on dwarf ULAS J115239.94+113407.6, index 146...
# Working on dwarf SDSS J115553.86+055957.5, index 147...
# Working on dwarf SDSSp J120358.19+001550.3, index 148...
# Working on dwarf WISE J120604.38+840110.6, index 149...
# Working on dwarf 2MASSI J1213033-043243, index 150...
# Working on dwarf SDSS J121440.95+631643.4, index 151...
# Working on dwarf WISEPC J121756.91+162640.2, index 152...
# Working on dwarf SDSS J121951.45+312849.4, index 153...
# Working on dwarf WISEA J122036.38+540717.3, index 154...
# Working on dwarf WISE J122152.28-313600.8, index 155...
# Working on dwarf WISE J122558.86-101345.0, index 156...
# Working on dwarf 2MASS J12314753+0847331, index 157...
# Working on dwarf CWISEP J124138.41-820051.9, index 158...
# Working on dwarf WISE J124309.61+844547.8, index 159...
# Working on dwarf WISE J125015.56+262846.9, index 160...
# Working on dwarf WISE J125448.52-072828.4, index 161...
# Working on dwarf WISE J125715.90+400854.2, index 162...
# Working on dwarf VHS J125804.89-441232.4, index 163...
# Working on dwarf WISE J130141.62-030212.9, index 164...
# Working on dwarf WISE J131833.98-175826.5, index 165...
# Working on dwarf PSO J201.0320+19.1072, index 166...
# Working on dwarf 2MASS J13243559+6358284, index 167...
# Working on dwarf SDSSp J132629.82-003831.5, index 168...
# Working on dwarf WISEA J133300.03-160754.4, index 169...
# Working on dwarf SDSS J135852.68+374711.9, index 170...
# Working on dwarf WISE J140035.40-385013.5, index 171...
# Working on dwarf WISEPC J140518.40+553421.4, index 172...
# Working on dwarf CWISE J141127.70-481153.4, index 173...
# Working on dwarf VHS J143311.46-083736.3, index 174...
# Working on dwarf WISEPA J143602.19-181421.8, index 175...
# Working on dwarf WISE J144806.48-253420.3, index 176...
# Working on dwarf WISE J150115.92-400418.4, index 177...
# Working on dwarf PSO J226.2599-28.8959, index 178...
# Working on dwarf WISE J151721.13+052929.3, index 179...
# Working on dwarf WISEPC J151906.64+700931.5, index 180...
# Working on dwarf SDSS J152039.82+354619.8, index 181...
# Working on dwarf WISE J152305.10+312537.6, index 182...
# Working on dwarf 2MASSI J1526140+204341, index 183...
# Working on dwarf SDSS J153453.33+121949.2, index 184...
# Working on dwarf CWISEP J153859.39+482659.1, index 185...
# Working on dwarf WISEPA J154151.66-225025.2, index 186...
# Working on dwarf WISE J154214.00+223005.2, index 187...
# Working on dwarf 2MASS J15461461+4932114, index 188...
# Working on dwarf CWISEP J160835.01-244244.7, index 189...
# Working on dwarf WISEPA J161215.94-342027.1, index 190...
# Working on dwarf WISEPA J161441.45+173936.7, index 191...
# Working on dwarf 2MASS J16150413+1340079, index 192...
# Working on dwarf SIMP J1619275+031350, index 193...
# Working on dwarf WISEPA J162208.94-095934.6, index 194...
# Working on dwarf WISEA J162341.27-740230.4, index 195...
# Working on dwarf PSO J247.3273+03.5932, index 196...
# Working on dwarf SDSS J163022.92+081822.0, index 197...
# Working on dwarf WISEA J163932.75+184049.4, index 198...
# Working on dwarf WISE J163940.86-684744.6, index 199...
# Working on dwarf WISEPA J165311.05+444423.9, index 200...
# Working on dwarf WISE J165842.56+510335.0, index 201...
# Working on dwarf CWISE J170127.12+415805.3, index 202...
# Working on dwarf WISE J170745.85-174452.5, index 203...
# Working on dwarf WISEPA J171104.60+350036.8, index 204...
# Working on dwarf PSO J258.2413+06.7612, index 205...
# Working on dwarf WISEPA J171717.02+612859.3, index 206...
# Working on dwarf WISE J172134.46+111739.4, index 207...
# Working on dwarf WISEA J173453.90-481357.9, index 208...
# Working on dwarf WISEA J173551.56-820900.3, index 209...
# Working on dwarf WISEPA J173835.53+273258.9, index 210...
# Working on dwarf WISE J173859.27+614242.1, index 211...
# Working on dwarf WISE J174102.78-464225.5, index 212...
# Working on dwarf WISE J174303.71+421150.0, index 213...
# Working on dwarf 2MASS J17461199+5034036, index 214...
# Working on dwarf WISE J174640.78-033818.0, index 215...
# Working on dwarf WISEA J175328.55-590447.6, index 216...
# Working on dwarf 2MASSJ17545447+1649196, index 217...
# Working on dwarf WISE J175510.28+180320.2, index 218...
# Working on dwarf WISEPA J180435.40+311706.1, index 219...
# Working on dwarf WISE J180952.53-044812.5, index 220...
# Working on dwarf WISE J181243.14+200746.4, index 221...
# Working on dwarf WISE J181329.40+283533.3, index 222...
# Working on dwarf WISEA J181849.59-470146.9, index 223...
# Working on dwarf WISEPA J182831.08+265037.8, index 224...
# Working on dwarf CWISE J183207.94-540943.3, index 225...
# Working on dwarf WISEPA J184124.74+700038.0, index 226...
# Working on dwarf WISE J185101.83+593508.6, index 227...
# Working on dwarf WISEA J190005.76-310810.9, index 228...
# Working on dwarf 2MASS J19010601+4718136, index 229...
# Working on dwarf WISE J191915.54+304558.4, index 230...
# Working on dwarf 2MASS J19251275+0700362, index 231...
# Working on dwarf CWISE J192636.29-342955.7, index 232...
# Working on dwarf WISE J192841.35+235604.9, index 233...
# Working on dwarf WISEA J193054.55-205949.4, index 234...
# Working on dwarf CWISEP J193518.59-154620.3, index 235...
# Working on dwarf WISENF J193656.08+040801.2, index 236...
# Working on dwarf WISE J195500.42-254013.9, index 237...
# Working on dwarf WISEPA J195905.66-333833.7, index 238...
# Working on dwarf WISE J200050.19+362950.1, index 239...
# Working on dwarf WISE J200520.38+542433.9, index 240...
# Working on dwarf WISE J200804.71-083428.5, index 241...
# Working on dwarf CWISEP J201146.45-481259.7, index 242...
# Working on dwarf CWISE J201221.32+701740.2, index 243...
# Working on dwarf WISE J201546.27+664645.1, index 244...
# Working on dwarf WISEA J201748.74-342102.6, index 245...
# Working on dwarf WISE J201920.76-114807.5, index 246...
# Working on dwarf WISE J203042.79+074934.7, index 247...
# Working on dwarf WISE J204356.42+622048.9, index 248...
# Working on dwarf WISEPC J205628.90+145953.3, index 249...
# Working on dwarf PSO J319.3102-29.6682, index 250...
# Working on dwarf WISE J212100.87-623921.6, index 251...
# Working on dwarf WISE J212321.92-261405.1, index 252...
# Working on dwarf 2MASS J21265916+7617440, index 253...
# Working on dwarf 2MASS J21373742+0808463, index 254...
# Working on dwarf WISE J214155.85-511853.1, index 255...
# Working on dwarf WISE J214706.78-102924.0, index 256...
# Working on dwarf 2MASS J21512543-2441000, index 257...
# Working on dwarf 2MASS J21522609+0937575, index 258...
# Working on dwarf 2MASS J21543318+5942187, index 259...
# Working on dwarf WISEPC J215751.38+265931.4, index 260...
# Working on dwarf WISEA J215949.54-480855.2, index 261...
# Working on dwarf PSO J330.3214+32.3686, index 262...
# Working on dwarf WISEA J220304.18+461923.4, index 263...
# Working on dwarf WISE J220905.73+271143.9, index 264...
# Working on dwarf 2MASS J22092183-2711329, index 265...
# Working on dwarf WISEPC J220922.10-273439.5, index 266...
# Working on dwarf WISEA J221140.53-475826.7, index 267...
# Working on dwarf WISE J221216.33-693121.6, index 268...
# Working on dwarf 2MASS J22153705+2110554, index 269...
# Working on dwarf WISE J222055.31-362817.4, index 270...
# Working on dwarf WISEA J223204.53-573010.4, index 271...
# Working on dwarf WISE J223617.59+510551.9, index 272...
# Working on dwarf WISE J223720.39+722833.8, index 273...
# Working on dwarf WISEP J223937.55+161716.2, index 274...
# Working on dwarf 2MASS J22490917+3205489, index 275...
# Working on dwarf 2MASS J22551861-5713056, index 276...
# Working on dwarf WISEPC J225540.74-311841.8, index 277...
# Working on dwarf CWISEP J225628.97+400227.3, index 278...
# Working on dwarf WISE J230133.32+021635.0, index 279...
# Working on dwarf WISEA J230228.66-713441.7, index 280...
# Working on dwarf WISEPA J231336.40-803700.3, index 281...
# Working on dwarf 2MASS J23174712-4838501, index 282...
# Working on dwarf WISEPC J231939.13-184404.3, index 283...
# Working on dwarf ULAS J232035.28+144829.8, index 284...
# Working on dwarf ULAS J232123.79+135454.9, index 285...
# Working on dwarf 2MASS J23254530+4251488, index 286...
# Working on dwarf ULAS J232600.40+020139.2, index 287...
# Working on dwarf WISEPC J232728.75-273056.5, index 288...
# Working on dwarf WISE J233226.49-432510.6, index 289...
# Working on dwarf 2MASSI J2339101+135230, index 290...
# Working on dwarf WISEPA J234351.20-741847.0, index 291...
# Working on dwarf WISEPC J234446.25+103415.8, index 292...
# Working on dwarf PM J23492+3458B, index 293...
# Working on dwarf WISEA J235402.79+024014.1, index 294...
# Working on dwarf WISE J235716.49+122741.8, index 295...
# Working on dwarf CWISE J002727.44-012101.7, index 296...
# Working on dwarf 2MASSI J0103320+193536, index 297...
# Working on dwarf WISE J013525.64+171503.4, index 298...
# Working on dwarf WISEPC J013836.59-032221.2, index 299...
# Working on dwarf WISEPA J030533.54+395434.4, index 300...
# Working on dwarf SDSS J032553.17+042540.1, index 301...
# Working on dwarf WISEA J083011.95+283716.0, index 302...
# Working on dwarf SDSS J104409.43+042937.6, index 303...
# Working on dwarf CWISEP J104756.81+545741.6, index 304...
# Working on dwarf CWISE J113833.47+721207.8, index 305...
# Working on dwarf 2MASS J11582077+0435014, index 306...
# Working on dwarf 2MASS J14075361+1241099, index 307...
# Working on dwarf CWISEP J144606.62-231717.8, index 308...
# Working on dwarf PSO J224.3820+47.4057, index 309...
# Working on dwarf CWISE J153347.50+175306.7, index 310...
# Working on dwarf WISE J154459.27+584204.5, index 311...
# Working on dwarf WISEA J172907.10-753017.0, index 312...
# Working on dwarf 2MASS J23312378-4718274, index 313...
# Working on dwarf SDSS J000112.18+153535.5, index 314...
# Working on dwarf PSO J001.1277-26.0675, index 315...
# Working on dwarf WISEPC J000849.76-173922.6, index 316...
# Working on dwarf PSO J003.3437-11.7168, index 317...
# Working on dwarf 2MASS J00150206+2959323, index 318...
# Working on dwarf 2MASSW J0015447+351603, index 319...
# Working on dwarf PSO J004.1834+23.0741, index 320...
# Working on dwarf PSO J004.6359+56.8370, index 321...
# Working on dwarf PSO J005.6302-06.8669, index 322...
# Working on dwarf 2MASS J00282091+2249050, index 323...
# Working on dwarf 2MASSW J0030300-145033, index 324...
# Working on dwarf 2MASS J00320509+0219017, index 327...
# Working on dwarf WISE J004024.88+090054.8, index 328...
# Working on dwarf PSO J011.1793-03.7847, index 329...
# Working on dwarf 2MASS J00464841+0715177, index 331...
# Working on dwarf WISEPC J004928.48+044100.1, index 332...
# Working on dwarf SIPS J0050-1538, index 333...
# Working on dwarf 2MASSW J0051107-154417, index 334...
# Working on dwarf WISEA J010202.11+035541.4, index 335...
# Working on dwarf SDSS J011912.22+240331.6, index 336...
# Working on dwarf 2MASS J01311838+3801554, index 338...
# Working on dwarf 2MASSW J0135358+120522, index 340...
# Working on dwarf SIMP J013656.5+093347.3, index 341...
# Working on dwarf PSO J024.4369+09.1360, index 342...
# Working on dwarf 2MASS J01414839-1601196, index 344...
# Working on dwarf 2MASS J01443536-0716142, index 345...
# Working on dwarf WISEPA J015010.86+382724.3, index 346...
# Working on dwarf ULAS J015024.37+135924.0, index 347...
# Working on dwarf HIP 9269B, index 349...
# Working on dwarf PSO J031.5651+20.9097, index 351...
# Working on dwarf 2MASSW J0208183+254253, index 352...
# Working on dwarf 2MASSW J0208236+273740, index 353...
# Working on dwarf 2MASS J02132062+3648506C, index 354...
# Working on dwarf 2MASSI J0213288+444445, index 355...
# Working on dwarf WISEPA J022105.94+384202.9, index 356...
# Working on dwarf 2MASS J02271036-1624479, index 358...
# Working on dwarf 2MASSW J0228110+253738, index 359...
# Working on dwarf 2MASS J02284243+1639329, index 360...
# Working on dwarf WISE J023038.90-022554.0, index 361...
# Working on dwarf PSO J041.5426+01.9456, index 363...
# Working on dwarf 2MASSI J0251148-035245, index 365...
# Working on dwarf PSO J045.3309-23.3226, index 366...
# Working on dwarf PSO J049.1159+26.8409, index 369...
# Working on dwarf 2MASSW J0320284-044636, index 370...
# Working on dwarf WISEA J032301.86+562558.0, index 371...
# Working on dwarf PSO J052.2746+13.3754, index 373...
# Working on dwarf SDSS J035104.37+481046.8, index 377...
# Working on dwarf WISE J040137.21+284951.7, index 378...
# Working on dwarf WISE J040418.01+412735.6, index 379...
# Working on dwarf 2MASS J04070885+1514565, index 380...
# Working on dwarf 2MASSI J0408290-145033, index 381...
# Working on dwarf PSO J062.3459+11.1794, index 382...
# Working on dwarf WISE J042417.94+072744.1, index 383...
# Working on dwarf PSO J069.7303+04.3834, index 385...
# Working on dwarf PSO J070.3773+04.7333, index 386...
# Working on dwarf PSO J071.8769-12.2713, index 387...
# Working on dwarf 2MASS J04474307-1936045, index 388...
# Working on dwarf 2MASSI J0453264-175154, index 390...
# Working on dwarf 2MASS J05160945-0445499, index 394...
# Working on dwarf HIP 26653B, index 396...
# Working on dwarf WISEPA J053957.02-103436.5, index 397...
# Working on dwarf PSO J085.1080-18.0445, index 398...
# Working on dwarf WISEPA J054231.26-162829.1, index 399...
# Working on dwarf WISEA J055007.94+161051.9, index 401...
# Working on dwarf PSO J087.7749-12.6537, index 402...
# Working on dwarf PSO J088.5709-00.1430, index 403...
# Working on dwarf PSO J089.1751-09.4513, index 404...
# Working on dwarf WISEA J060742.13+455037.0, index 406...
# Working on dwarf 2MASS J06143818+3950357, index 408...
# Working on dwarf WISEPA J062309.94-045624.6, index 409...
# Working on dwarf WISEPA J062542.21+564625.5, index 410...
# Working on dwarf 2MASSI J0652307+471034, index 414...
# Working on dwarf WISEPA J065609.60+420531.0, index 415...
# Working on dwarf WISEA J065958.55+171710.9, index 416...
# Working on dwarf WISEA J071552.38-114532.9, index 417...
# Working on dwarf 2MASS J07231462+5727081, index 418...
# Working on dwarf 2MASS J07415784+0531568, index 420...
# Working on dwarf PSO J117.0600-01.6779, index 423...
# Working on dwarf HIP 38939B, index 425...
# Working on dwarf ULAS J080918.41+212615.2, index 428...
# Working on dwarf ULAS J081110.86+252931.8, index 430...
# Working on dwarf WISEPA J081958.05-033529.0, index 432...
# Working on dwarf 2MASSW J0820299+450031, index 433...
# Working on dwarf WISEPA J082131.63+144319.3, index 434...
# Working on dwarf 2MASS J08234818+2428577, index 435...
# Working on dwarf 2MASSW J0829066+145622, index 437...
# Working on dwarf PSO J127.5648-11.1861, index 438...
# Working on dwarf SDSS J083048.80+012831.1, index 439...
# Working on dwarf 2MASSW J0832045-012835, index 440...
# Working on dwarf 2MASS J08355829+0548308, index 441...
# Working on dwarf SDSSp J083717.22-000018.3, index 442...
# Working on dwarf PSO J130.7271-06.1732, index 443...
# Working on dwarf PSO J133.8016-02.5658, index 445...
# Working on dwarf ULAS J085910.69+101017.1, index 449...
# Working on dwarf PSO J135.7840+16.9932, index 450...
# Working on dwarf PSO J136.5380-14.3267, index 452...
# Working on dwarf 2MASSI J0908380+503208, index 453...
# Working on dwarf Gl 337CD, index 454...
# Working on dwarf 2MASS J09153413+0422045, index 455...
# Working on dwarf 2MASS J09211410-2104446, index 457...
# Working on dwarf SDSS J092308.70+234013.7, index 458...
# Working on dwarf WISEPC J092906.77+040957.9, index 459...
# Working on dwarf 2MASS J09490860-1545485, index 460...
# Working on dwarf ULAS J095429.90+062309.6, index 461...
# Working on dwarf PSO J149.1907-19.1730, index 463...
# Working on dwarf 2MASS J09593276+4523309, index 464...
# Working on dwarf SDSS J100711.74+193056.2, index 465...
# Working on dwarf DENIS J1019245-270717, index 468...
# Working on dwarf 2MASSI J1029216+162652, index 469...
# Working on dwarf ULAS J102940.52+093514.6, index 470...
# Working on dwarf SDSS J103026.78+021306.4, index 471...
# Working on dwarf PSO J159.2399-26.3885, index 472...
# Working on dwarf SDSS J103931.35+325625.5, index 474...
# Working on dwarf PSO J160.0416-21.3281, index 475...
# Working on dwarf SDSS J104842.84+011158.5, index 479...
# Working on dwarf 2MASS J10511900+5613086, index 481...
# Working on dwarf 2MASS J10595185+3042059, index 483...
# Working on dwarf 2MASS J11000965+4957470, index 484...
# Working on dwarf Gl 417BC, index 486...
# Working on dwarf WISEPC J112254.73+255021.5, index 487...
# Working on dwarf WISEA J114724.10-204021.3, index 489...
# Working on dwarf 2MASS J11533966+5032092, index 490...
# Working on dwarf ULAS J115508.39+044502.3, index 491...
# Working on dwarf SDSS J115700.50+061105.2, index 493...
# Working on dwarf DENIS-P J1159+0057, index 494...
# Working on dwarf PSO J180.1475-28.6160, index 495...
# Working on dwarf 2MASSI J1204303+321259, index 497...
# Working on dwarf ULAS J120444.67-015034.9, index 498...
# Working on dwarf SDSS J120602.51+281328.7, index 499...
# Working on dwarf SDSS J120747.17+024424.8, index 500...
# Working on dwarf 2MASS J12212770+0257198, index 503...
# Working on dwarf 2MASS J12312141+4959234, index 505...
# Working on dwarf 2MASS J12321827-0951502, index 507...
# Working on dwarf NLTT 31450B, index 508...
# Working on dwarf 2MASSW J1246467+402715, index 509...
# Working on dwarf SDSS J125011.65+392553.9, index 510...
# Working on dwarf 2MASS J12565688+0146163, index 513...
# Working on dwarf 2MASSW J1300425+191235, index 515...
# Working on dwarf ULAS J131610.13+031205.5, index 516...
# Working on dwarf 2MASSW J1326201-272937, index 518...
# Working on dwarf PSO J202.1635-03.7660, index 520...
# Working on dwarf 2MASS J13373116+4938367, index 521...
# Working on dwarf WISE J133750.46+263648.6, index 522...
# Working on dwarf 2MASSW J1338261+414034, index 523...
# Working on dwarf 2MASS J13384944+0437315, index 524...
# Working on dwarf 2MASSW J1343167+394508, index 525...
# Working on dwarf LHS 2803B, index 526...
# Working on dwarf PSO J207.7496+29.4240, index 527...
# Working on dwarf SDSS J140023.12+433822.3, index 529...
# Working on dwarf 2MASSW J1411175+393636, index 530...
# Working on dwarf 2MASSW J1412244+163312, index 531...
# Working on dwarf SDSS J141530.05+572428.7, index 532...
# Working on dwarf 2MASSW J1421314+182740, index 533...
# Working on dwarf 2MASS J14283132+5923354, index 534...
# Working on dwarf SDSS J143553.25+112948.6, index 536...
# Working on dwarf 2MASSW J1448256+103159, index 539...
# Working on dwarf HIP 73169B, index 540...
# Working on dwarf WISEPC J145715.03+581510.2, index 541...
# Working on dwarf HIP 73786B, index 543...
# Working on dwarf 2MASSW J1506544+132106, index 545...
# Working on dwarf SDSS J151240.67+340350.1, index 546...
# Working on dwarf 2MASSW J1515008+484742, index 547...
# Working on dwarf SDSS J151506.11+443648.3, index 548...
# Working on dwarf SDSS J151643.01+305344.4, index 549...
# Working on dwarf SDSS J152103.24+013142.7, index 552...
# Working on dwarf 2MASS J15230657-2347526, index 553...
# Working on dwarf SDSS J154009.36+374230.3, index 556...
# Working on dwarf VHS J154352.78-043909.6, index 557...
# Working on dwarf 2MASS J15485834-1636018, index 560...
# Working on dwarf 2MASS J15500845+1455180, index 561...
# Working on dwarf SDSS J155120.86+432930.3, index 562...
# Working on dwarf 2MASSW J1615441+355900, index 563...
# Working on dwarf WISEPA J161705.75+180714.3, index 564...
# Working on dwarf SDSS J161928.31+005011.9, index 565...
# Working on dwarf PSO J246.1033-19.6194, index 566...
# Working on dwarf WISEPA J162725.64+325525.5, index 567...
# Working on dwarf SDSS J163030.53+434404.0, index 570...
# Working on dwarf WISE J163236.47+032927.3, index 571...
# Working on dwarf WISE J163645.56-074325.1, index 572...
# Working on dwarf 2MASS J16452207+3004071, index 573...
# Working on dwarf WISEPA J164715.59+563208.2, index 574...
# Working on dwarf 2MASS J16573454+1054233, index 576...
# Working on dwarf 2MASS J17114559+4028578, index 579...
# Working on dwarf PSO J260.9762+04.2354, index 582...
# Working on dwarf WISEPA J172844.93+571643.6, index 583...
# Working on dwarf WISE J173421.02+502349.9, index 584...
# Working on dwarf WISE J174113.12+132711.9, index 585...
# Working on dwarf SDSS J175024.01+422237.8, index 589...
# Working on dwarf SDSSp J175032.96+175903.9, index 590...
# Working on dwarf 2MASS J17545447+1649196, index 591...
# Working on dwarf 2MASS J18000116-1559235, index 593...
# Working on dwarf WISEP J180026.60+013453.1, index 594...
# Working on dwarf PSO J272.0887-04.9943, index 595...
# Working on dwarf WISE J180901.07+383805.4, index 596...
# Working on dwarf PSO J276.8234+22.4380, index 599...
# Working on dwarf WISEPA J185215.78+353716.3, index 601...
# Working on dwarf WISEPA J190624.75+450808.2, index 603...
# Working on dwarf DENIS-P J1909081-193748, index 604...
# Working on dwarf 2MASS J20025073-0521524, index 609...
# Working on dwarf WISE J201404.13+042408.5, index 611...
# Working on dwarf SDSS J202820.32+005226.5, index 612...
# Working on dwarf UGPS J20480024+503821.9, index 614...
# Working on dwarf 2MASSI J2107316-030733, index 615...
# Working on dwarf SDSS J212413.89+010000.3, index 618...
# Working on dwarf 2MASSW J2130446-084520, index 619...
# Working on dwarf PSO J323.1320+29.5308, index 620...
# Working on dwarf 2MASS J21324898-1452544, index 621...
# Working on dwarf PSO J327.1504+22.6612, index 624...
# Working on dwarf 2MASS J21580457-1550098, index 627...
# Working on dwarf WISEPC J221354.69+091139.4, index 631...
# Working on dwarf WISE J222219.93+302601.4, index 633...
# Working on dwarf WISEA J223343.53-133140.9, index 634...
# Working on dwarf WISEPC J223729.53-061434.2, index 636...
# Working on dwarf WISEPC J223937.55+161716.2, index 637...
# Working on dwarf PSO J341.4606-28.7798, index 638...
# Working on dwarf WISEA J230329.45+315022.7, index 641...
# Working on dwarf ULAS J230601.02+130225.0, index 642...
# Working on dwarf PSO J346.5281-15.9406, index 643...
# Working on dwarf SSSPM J2310-1759, index 644...
# Working on dwarf 2MASS J23185497-1301106, index 645...
# Working on dwarf CFBDS J232304.41-015232.3, index 647...
# Working on dwarf PSO J353.6355+13.2209, index 650...
# Working on dwarf WISE J233543.79+422255.2, index 651...
# Working on dwarf PSO J354.3709+57.7939, index 652...
# Working on dwarf 2MASS J23392527+3507165, index 654...
# Working on dwarf ULAS J234228.97+085620.1, index 655...
# Working on dwarf 2MASS J23440624-0733282, index 656...
# Working on dwarf WISEPC J234841.10-102844.4, index 657...
# Working on dwarf PM I23492+3458B, index 658...
# Working on dwarf PSO J357.8314+49.6330, index 659...
# Working on dwarf DENIS J2354599-185221, index 660...
# Working on dwarf SDSS J000013.54+255418.6, index 662...
# Working on dwarf 2MASSI J0003422-282241, index 664...
# Working on dwarf WISEA J000430.66-260402.3, index 665...
# Working on dwarf LHS 102BC, index 666...
# Working on dwarf 2MASS J00044144-2058298, index 667...
# Working on dwarf 2MASS J00045753-1709369, index 668...
# Working on dwarf 2MASS J00054844-2157196, index 670...
# Working on dwarf 2MASSI J0006205-172051, index 671...
# Working on dwarf LP 704-48, index 672...
# Working on dwarf SDSS J000649.16-085246.3, index 673...
# Working on dwarf DENIS J0006579-643654, index 674...
# Working on dwarf 2MASS J00070787-2458042, index 675...
# Working on dwarf 2MASS J00100009-2031122, index 677...
# Working on dwarf LSR J0011+5908, index 678...
# Working on dwarf 2MASS J00132229-1143006, index 679...
# Working on dwarf 2MASSI J0013578-223520, index 680...
# Working on dwarf 2MASS J00135882-1816462, index 681...
# Working on dwarf HD 984 B, index 682...
# Working on dwarf WISEA J001450.17-083823.4, index 683...
# Working on dwarf 2MASS J00145575-4844171, index 684...
# Working on dwarf HD 1160B, index 688...
# Working on dwarf SDSS J001637.62-103911.2, index 689...
# Working on dwarf 2MASS J00165953-4056541, index 691...
# Working on dwarf 2MASS J00182834-6703130, index 692...
# Working on dwarf 2MASS J00184613-6356122, index 694...
# Working on dwarf PSO J004.7818+41.0231, index 695...
# Working on dwarf SDSS J001911.65+003017.8, index 696...
# Working on dwarf 2MASS J00191296-6226005, index 697...
# Working on dwarf 2MASS J00192626+4614078, index 698...
# Working on dwarf NLTT 1011B, index 699...
# Working on dwarf 2MASS J00193927-3724392, index 700...
# Working on dwarf 2MASSI J0019457+521317, index 701...
# Working on dwarf Koenigstuhl 1B, index 702...
# Working on dwarf Koenigstuhl 1A, index 703...
# Working on dwarf SDSS J002209.31-011040.2, index 704...
# Working on dwarf BRI 0021-0214, index 706...
# Working on dwarf LHS 1070, index 707...
# Working on dwarf 2MASSI J0025036+475919, index 708...
# Working on dwarf LHS 1074, index 709...
# Working on dwarf SDSS J002611.45-094341.1, index 710...
# Working on dwarf WISEA J002656.73-542854.8, index 711...
# Working on dwarf PC 0025+0447, index 712...
# Working on dwarf LP 349-25, index 713...
# Working on dwarf 2MASS J00285545-1927165, index 715...
# Working on dwarf DENIS-P J003006.2-373948, index 716...
# Working on dwarf HIP 2397B, index 717...
# Working on dwarf 2MASSW J0030438+313932, index 719...
# Working on dwarf DENIS J0031192-384035, index 721...
# Working on dwarf 2MASS J00315477+0649463, index 723...
# Working on dwarf 2MASSI J0032431-223727, index 726...
# Working on dwarf EROS-MP J0032-4405, index 727...
# Working on dwarf SDSSp J003259.36+141036.6, index 728...
# Working on dwarf 2MASS J00332386-1521309, index 729...
# Working on dwarf ULAS J003402.77-005206.7, index 730...
# Working on dwarf 2MASS J00344300-4102266, index 731...
# Working on dwarf 2MASSI J0034568-070601, index 733...
# Working on dwarf 2MASSW J0036159+182110, index 734...
# Working on dwarf 2MASS J00374306-5846229, index 735...
# Working on dwarf 2MASS J00381489-6403529, index 736...
# Working on dwarf SDSS J003843.99+134339.5, index 738...
# Working on dwarf HD 3651B, index 739...
# Working on dwarf HD 3861B, index 741...
# Working on dwarf 2MASS J00412179+3547133, index 742...
# Working on dwarf DENIS-P J0041353-562112, index 743...
# Working on dwarf SDSS J004154.54+134135.5, index 744...
# Working on dwarf 2MASS J00425923+1142104, index 745...
# Working on dwarf WISEA J004326.26+222124.0, index 746...
# Working on dwarf LHS 1135, index 747...
# Working on dwarf 2MASSW J0045214+163445, index 749...
# Working on dwarf 2MASS J00461551+0252004, index 751...
# Working on dwarf WISEP J004701.06+680352.1, index 753...
# Working on dwarf 2MASS J00501994-3322402, index 756...
# Working on dwarf RG 0050-2722, index 759...
# Working on dwarf 2MASS J00531899-3631102, index 760...
# Working on dwarf SDSSp J005406.55-003101.8, index 761...
# Working on dwarf LHS 1166, index 762...
# Working on dwarf SDSS J005705.55-084624.2, index 763...
# Working on dwarf 2MASSW J0058425-065123, index 764...
# Working on dwarf CFBDS J005910.90-011401.3, index 765...
# Working on dwarf LHS 132, index 767...
# Working on dwarf 2MASS J01062285-5933185, index 769...
# Working on dwarf ULAS2MASS J0106+1518, index 770...
# Working on dwarf 2MASS J01071607-1517577, index 771...
# Working on dwarf SDSSp J010752.33+004156.1, index 772...
# Working on dwarf SSSPM J0109-5101, index 773...
# Working on dwarf SSSPM J0109-4955, index 774...
# Working on dwarf 2MASS J01092170+2949255, index 775...
# Working on dwarf 2MASS J01095117-0343264, index 776...
# Working on dwarf WISEA J011639.05-165420.5, index 777...
# Working on dwarf DENIS J0116529-645557, index 778...
# Working on dwarf 2MASS J01165457-1357342, index 779...
# Working on dwarf 2MASSI J0117474-340325, index 780...
# Working on dwarf HIP 6217C, index 782...
# Working on dwarf 2MASS J01204916-0741036, index 783...
# Working on dwarf 2MASS J01205114-5200349, index 784...
# Working on dwarf HIP 6407B, index 785...
# Working on dwarf 2MASS J01231125-6921379, index 786...
# Working on dwarf SSSPM J0124-4240, index 788...
# Working on dwarf SERC 296A, index 789...
# Working on dwarf 2MASSI J0125369-343505, index 790...
# Working on dwarf 2MASS J01262109+1428057, index 791...
# Working on dwarf 2MASS J01265327-5505506, index 792...
# Working on dwarf CTI 012657.5+280202, index 793...
# Working on dwarf 2MASS J01282664-5545343, index 794...
# Working on dwarf 2MASS J01294256-0823580, index 795...
# Working on dwarf WISEA J013012.66-104732.4, index 796...
# Working on dwarf 2MASS J01303563-4445411, index 797...
# Working on dwarf SSSPM J0134-6315, index 800...
# Working on dwarf ULAS J013346.25+132822.4, index 801...
# Working on dwarf 2MASS J01344601-5707564, index 802...
# Working on dwarf LHS 1265, index 803...
# Working on dwarf L 726-8, index 809...
# Working on dwarf 2MASSW J0141032+180450, index 810...
# Working on dwarf 2MASS J01411479-2417311, index 811...
# Working on dwarf 2MASS J01415823-4633574, index 813...
# Working on dwarf 2MASS J01423153+0523285, index 814...
# Working on dwarf 2MASS J01460119-4545263, index 816...
# Working on dwarf 2MASS J01463192+0641153, index 817...
# Working on dwarf 2MASS J01473282-4954478, index 819...
# Working on dwarf 2MASSW J0147334+345311, index 820...
# Working on dwarf WISEPC J014807.25-720258.7, index 821...
# Working on dwarf 2MASS J01483864-3024396, index 822...
# Working on dwarf 2MASSW J0149090+295613, index 823...
# Working on dwarf SDSS J015141.69+124429.6, index 826...
# Working on dwarf GSC 08047-00232B, index 827...
# Working on dwarf SDSS J015354.23+140452.9, index 828...
# Working on dwarf GD 280B, index 829...
# Working on dwarf WISEA J020201.25-313645.2, index 832...
# Working on dwarf 2MASS J02042212-3632308, index 833...
# Working on dwarf DENIS J020529.0-115925, index 835...
# Working on dwarf ULAS J020533.75+123824.1, index 836...
# Working on dwarf WISEPA J020625.26+264023.6, index 838...
# Working on dwarf SDSS J020735.60+135556.3, index 839...
# Working on dwarf SDSS J020742.48+000056.2, index 840...
# Working on dwarf 2MASS J02103857-3015313, index 843...
# Working on dwarf 2MASS J02150802-3040011, index 846...
# Working on dwarf 2MASSI J0218291-313322, index 847...
# Working on dwarf 2MASS J02185792-0617499, index 848...
# Working on dwarf 2MASS J02192196+0506306, index 849...
# Working on dwarf 2MASS J02192210-3925225A, index 850...
# Working on dwarf SSSPM J0219-1939, index 851...
# Working on dwarf 2MASS J02212859-6831400, index 853...
# Working on dwarf 2MASS J02215494-5412054, index 854...
# Working on dwarf WISEPC J022322.39-293258.1, index 855...
# Working on dwarf PSO J035.8683-15.1937, index 856...
# Working on dwarf HIP 11161B, index 857...
# Working on dwarf 2MASS J02235464-5815067, index 858...
# Working on dwarf DENIS J0224120-763320, index 859...
# Working on dwarf 2MASS J02251947-5837295, index 860...
# Working on dwarf 2MASS J02265658-5327032, index 862...
# Working on dwarf 2MASS J02283305+1811097, index 865...
# Working on dwarf 2MASS J02284355-6325052, index 867...
# Working on dwarf 2MASS J02301551+2704061, index 868...
# Working on dwarf 2MASS J02304442-3027275, index 870...
# Working on dwarf DENIS J0230450-095305, index 871...
# Working on dwarf NLTT 8245B, index 873...
# Working on dwarf 2MASS J02340093-6442068, index 874...
# Working on dwarf WISEA J023421.83+601227.3, index 875...
# Working on dwarf SDSS J023547.56-084919.8, index 876...
# Working on dwarf GJ 1048B, index 877...
# Working on dwarf PSO J039.6352-21.7746, index 878...
# Working on dwarf 2MASSI J0239424-173547, index 879...
# Working on dwarf 2MASS J02402950+2832576, index 880...
# Working on dwarf 2MASS J02404759-4253377, index 881...
# Working on dwarf 2MASS J02410564-5511466, index 882...
# Working on dwarf 2MASS J02411151-0326587, index 883...
# Working on dwarf LSPM J0241+2553B, index 885...
# Working on dwarf 2MASSI J0241536-124106, index 886...
# Working on dwarf 2MASSI J0243137-245329, index 887...
# Working on dwarf 2MASS J02435103-5432194, index 888...
# Working on dwarf 2MASS J02441019-3548036, index 889...
# Working on dwarf BR B0246-1703, index 892...
# Working on dwarf 2MASS J02495639-0557352, index 893...
# Working on dwarf TVLM 831-154910, index 894...
# Working on dwarf TVLM 831-161058, index 895...
# Working on dwarf TVLM 831-165166, index 897...
# Working on dwarf TVLM 832-10443, index 898...
# Working on dwarf Teegarden's Star, index 899...
# Working on dwarf 2MASS J02534448-7959133, index 900...
# Working on dwarf 2MASS J02535980+3206373, index 901...
# Working on dwarf PSO J043.5395+02.3995, index 902...
# Working on dwarf DENIS-P J025503.3-470049, index 903...
# Working on dwarf HIP 13589B, index 904...
# Working on dwarf 2MASS J02572581-3105523, index 905...
# Working on dwarf WISEA J030119.39-231921.1, index 906...
# Working on dwarf TVLM 832-42500, index 907...
# Working on dwarf WISEA J030237.52-581740.3, index 908...
# Working on dwarf WISEA J030601.66-033059.0, index 911...
# Working on dwarf SSSPM J0306-3648, index 912...
# Working on dwarf HD 19467B, index 913...
# Working on dwarf WISEA J030845.36+325923.1, index 914...
# Working on dwarf WISE J030919.67-501614.3, index 915...
# Working on dwarf 2MASS J03093877-3014352, index 916...
# Working on dwarf 2MASS J03100053+0726506, index 917...
# Working on dwarf 2MASSW J0310599+164816, index 918...
# Working on dwarf 2MASS J03111547+0106307, index 919...
# Working on dwarf 2MASS J03134443+0433165, index 921...
# Working on dwarf 2MASS J03140344+1603056, index 922...
# Working on dwarf DENIS J031433.1-462339, index 923...
# Working on dwarf 2MASS J03144011-0450316, index 924...
# Working on dwarf 2MASSI J0316451-284852, index 928...
# Working on dwarf 2MASS J03182597-3708118, index 929...
# Working on dwarf 2MASS J03201720-1026124, index 931...
# Working on dwarf LP 412-31, index 933...
# Working on dwarf 2MASS J03224622-7940595, index 934...
# Working on dwarf WISEA J032309.12-590751.0, index 936...
# Working on dwarf 2MASS J03231002-4631237, index 937...
# Working on dwarf WISEA J032504.52-504403.0, index 939...
# Working on dwarf 2MASSW J0326137+295015, index 943...
# Working on dwarf 2MASS J03283463+1129515, index 944...
# Working on dwarf 2MASSI J0328426+230205, index 945...
# Working on dwarf 2MASS J03300506+2405281, index 947...
# Working on dwarf LSPM J0330+3504, index 948...
# Working on dwarf LEHPM 1-3365, index 950...
# Working on dwarf LSPM J0330+5413, index 951...
# Working on dwarf 2MASS J03313025-3042383, index 953...
# Working on dwarf 2MASS J03320043-2317496, index 954...
# Working on dwarf 2MASS J03333313-3215181, index 955...
# Working on dwarf ULAS J033350.84+001406.1, index 956...
# Working on dwarf LEHPM 3396, index 957...
# Working on dwarf 2MASSI J0335020+234235, index 958...
# Working on dwarf 2MASS J03354535+0658058, index 960...
# Working on dwarf WISE J033713.43+114824.5, index 964...
# Working on dwarf 2MASS J03390160-2434059, index 965...
# Working on dwarf LP 944-20, index 966...
# Working on dwarf 1RXS J034231.8+121622 B, index 968...
# Working on dwarf SDSS J034408.91+011124.9, index 969...
# Working on dwarf 2MASP J0345432+254023, index 970...
# Working on dwarf 2MASS J03480772-6022270, index 971...
# Working on dwarf 2MASS J03505737+1818069, index 973...
# Working on dwarf LHS 1604, index 974...
# Working on dwarf 2MASS J03521086+0210479, index 976...
# Working on dwarf SDSS J035308.54+103056.0, index 977...
# Working on dwarf 2MASS J03540135+2316339, index 978...
# Working on dwarf 2MASS J03550477-1032415, index 979...
# Working on dwarf 2MASS J03552337+1133437, index 980...
# Working on dwarf SDSS J035721.11-064126.0, index 981...
# Working on dwarf DENIS-P J035726.9-441730, index 982...
# Working on dwarf 2MASS J04012977-4050448, index 984...
# Working on dwarf LSPM J0402+1730, index 986...
# Working on dwarf WISEA J040443.50-642030.0, index 988...
# Working on dwarf 2MASS J04070752+1546457, index 989...
# Working on dwarf 2MASS J04081032+0742494, index 991...
# Working on dwarf Hya03, index 995...
# Working on dwarf SDSSp J041320.38-011424.9, index 996...
# Working on dwarf 2MASSI J0415195-093506, index 998...
# Working on dwarf 2MASS J04173745-0800007, index 999...
# Working on dwarf 2MASS J04174743-2129191, index 1000...
# Working on dwarf LSR J0419+4233, index 1001...
# Working on dwarf Hya01, index 1002...
# Working on dwarf 2MASS J04203904+2355502, index 1003...
# Working on dwarf LP 415-20, index 1004...
# Working on dwarf Hya06, index 1005...
# Working on dwarf 2MASS J04221413+1530525, index 1006...
# Working on dwarf SDSS J042230.66+072342.9, index 1007...
# Working on dwarf SDSSp J042348.57-041403.5, index 1008...
# Working on dwarf 2MASS J04235322-0006587, index 1009...
# Working on dwarf LHS 191, index 1011...
# Working on dwarf 2MASS J04270723+0859027, index 1012...
# Working on dwarf DENIS-P J04272708-1127143, index 1013...
# Working on dwarf 2MASSI J0428510-225323, index 1014...
# Working on dwarf 2MASSI J0429184-312356, index 1015...
# Working on dwarf CFHT-Hy-20, index 1016...
# Working on dwarf 2MASS J04305157-0849007, index 1017...
# Working on dwarf Cl* Melotte 25 DKJ 14784e, index 1019...
# Working on dwarf 2MASS J04351455-1414468, index 1020...
# Working on dwarf LP 775-031, index 1021...
# Working on dwarf WISEA J043535.82+211508.9, index 1022...
# Working on dwarf 2MASS J04362054-4218523, index 1023...
# Working on dwarf 2MASS J04362767+1151243, index 1024...
# Working on dwarf 2MASS J04362788-4114465, index 1025...
# Working on dwarf 2MASS J04365019-1803262, index 1026...
# Working on dwarf 2MASSI J0439010-235308, index 1028...
# Working on dwarf NLTT 13728, index 1029...
# Working on dwarf 2MASS J04402583-1820414, index 1030...
# Working on dwarf 2MASS 0441+2301 Aab, index 1032...
# Working on dwarf 2MASS J04433761+0002051, index 1034...
# Working on dwarf 2MASS J04441479+0543573, index 1035...
# Working on dwarf 2MASS J04451119-0602526, index 1036...
# Working on dwarf 2MASS J04453237-3642258, index 1037...
# Working on dwarf 2MASSI J0445538-304820, index 1038...
# Working on dwarf LHS 197, index 1039...
# Working on dwarf 2MASS J04493288+1607226, index 1043...
# Working on dwarf 2MASSI J0451009-340214, index 1044...
# Working on dwarf APMPM J0452-5819, index 1045...
# Working on dwarf LEHPM 2-59, index 1046...
# Working on dwarf Gaia J0452-36B, index 1047...
# Working on dwarf 2MASS J04553267-2701493, index 1049...
# Working on dwarf 2MASS J04572565+6809177, index 1050...
# Working on dwarf 2MASS J04584239-3002061, index 1052...
# Working on dwarf Hya08, index 1053...
# Working on dwarf WISEA J045921.21+154059.2, index 1055...
# Working on dwarf 2MASS J05002100+0330501, index 1057...
# Working on dwarf 2MASS J05012406-0010452, index 1058...
# Working on dwarf 2MASSI J0502134+144236, index 1059...
# Working on dwarf 2MASS J05084947-1647167, index 1061...
# Working on dwarf LSR J0510+2713, index 1062...
# Working on dwarf LHS 1742a, index 1063...
# Working on dwarf 2MASS J05110163-4606015, index 1064...
# Working on dwarf 2MASS J05123569-3041067, index 1066...
# Working on dwarf WISEPA J051317.28+060814.7, index 1067...
# Working on dwarf LSR J0515+5911, index 1068...
# Working on dwarf 2MASS J05170548-4154413, index 1070...
# Working on dwarf 2MASS J05173766-3349027, index 1071...
# Working on dwarf 2MASS J05181131-3101529, index 1072...
# Working on dwarf 2MASS J05184616-2756457, index 1073...
# Working on dwarf 2MASS J05185995-2828372, index 1074...
# Working on dwarf UGPS J052127.27+364048.6, index 1076...
# Working on dwarf 2MASSI J0523382-140302, index 1077...
# Working on dwarf 2MASS J05253876-7426008, index 1078...
# Working on dwarf 2MASS J05264316-1824315, index 1079...
# Working on dwarf 2MASS J05264348-4455455, index 1080...
# Working on dwarf 2MASS J05265973-5026216, index 1081...
# Working on dwarf 2MASS J05284435-3252228, index 1082...
# Working on dwarf WISEPA J052844.51-330823.9, index 1083...
# Working on dwarf 2MASS J05325346+8246465, index 1084...
# Working on dwarf WISEA J053257.29+041842.5, index 1085...
# Working on dwarf 2MASS J05345844-1511439, index 1086...
# Working on dwarf 2MASS J05361998-1920396, index 1088...
# Working on dwarf LHS 207, index 1089...
# Working on dwarf 2MASS J05392474+4038437, index 1090...
# Working on dwarf SDSSp J053951.99-005902.0, index 1092...
# Working on dwarf 2MASS J05431887+6422528, index 1097...
# Working on dwarf 2MASS J05441150-2433018, index 1098...
# Working on dwarf 2MASS J05575096-1359503, index 1104...
# Working on dwarf APMPM J0559-2903, index 1105...
# Working on dwarf 2MASS J05591914-1404488, index 1106...
# Working on dwarf 2MASS J06003375-3314268, index 1107...
# Working on dwarf 2MASS J06022216+6336391, index 1109...
# Working on dwarf LSR J0602+3910, index 1110...
# Working on dwarf 2MASS J06050196-2342270, index 1111...
# Working on dwarf WISEP J060738.65+242953.4, index 1112...
# Working on dwarf 2MASS J06080232-2944590, index 1114...
# Working on dwarf 2MASS J06085283-2753583, index 1115...
# Working on dwarf CD-35 2722B, index 1116...
# Working on dwarf Gl 229B, index 1117...
# Working on dwarf WISEPA J061135.13-041024.0, index 1118...
# Working on dwarf WISEPA J061213.93-303612.7, index 1119...
# Working on dwarf HD 253662B, index 1120...
# ...
# Working on dwarf SDSS J163817.31+321144.0, index 2044...
# Working on dwarf WISE J163940.83-684738.6, index 2045...
# Working on dwarf 2MASS J16403197+1231068, index 2046...
# Working on dwarf SDSS J164238.60+330855.6, index 2047...
# Working on dwarf HIP 81910B, index 2048...
# Working on dwarf SDSS J164438.14+284614.5, index 2049...
# Working on dwarf SDSS J164439.66+260013.3, index 2050...
# Working on dwarf 2MASSW J1645221-131951, index 2052...
# Working on dwarf LHS 3241, index 2053...
# Working on dwarf SDSS J164748.33+190933.7, index 2055...
# Working on dwarf 2MASS J16490419+0444571, index 2056...
# Working on dwarf SDSS J165031.33+352359.5, index 2057...
# Working on dwarf SDSS J165329.69+623136.5, index 2059...
# Working on dwarf SDSS J165450.79+374714.6, index 2060...
# Working on dwarf vB 8, index 2061...
# Working on dwarf 2MASSW J1658037+702701, index 2063...
# Working on dwarf SDSS J165850.26+182000.6, index 2065...
# Working on dwarf SDSS J170302.52+355824.3, index 2066...
# Working on dwarf SDSS J170316.71+190636.0, index 2067...
# Working on dwarf DENIS-P J170547.4-544151, index 2068...
# Working on dwarf DENIS-P J170548.38-051645.7, index 2069...
# Working on dwarf 2MASS J17065487-1314396, index 2070...
# Working on dwarf 2MASS J17071830+6439331, index 2071...
# Working on dwarf 2MASS J17072343-0558249, index 2072...
# Working on dwarf DENIS J1707252-013809, index 2073...
# Working on dwarf 2MASSI J1707333+430130, index 2074...
# Working on dwarf SDSS J171049.35+332325.2, index 2076...
# Working on dwarf 2MASS J17111353+2326333, index 2078...
# Working on dwarf 2MASSI J1711457+223204, index 2080...
# Working on dwarf NLTT 44368B, index 2081...
# Working on dwarf GJ 660.1B, index 2082...
# Working on dwarf SDSS J171319.23+292816.1, index 2084...
# Working on dwarf SDSS J171714.10+652622.2, index 2085...
# Working on dwarf LSPM J1717+5925B, index 2087...
# Working on dwarf 2MASSI J1721039+334415, index 2088...
# Working on dwarf SDSS J172244.32+632946.8, index 2090...
# Working on dwarf SDSS J172543.84+532534.9, index 2092...
# Working on dwarf 2MASSI J1726000+153819, index 2093...
# Working on dwarf HIP 85365B, index 2094...
# Working on dwarf VVV BD001, index 2095...
# Working on dwarf 2MASS J17281134+0839590, index 2096...
# Working on dwarf 2MASSW J1728114+394859, index 2097...
# Working on dwarf 2MASS J17312974+2721233, index 2099...
# Working on dwarf 2MASS J17320014+2656228, index 2100...
# Working on dwarf 2MASS J17331893+4633593, index 2101...
# Working on dwarf WISE J173332.50+314458.3, index 2102...
# Working on dwarf DENIS-P J1733423-165449, index 2103...
# Working on dwarf 2MASS J17343053-1151388, index 2105...
# Working on dwarf LSPM J1735+2634, index 2106...
# Working on dwarf WISE J173551.72-820900.1, index 2107...
# Working on dwarf 2MASS J17392515+2454421, index 2109...
# Working on dwarf WISEPA J174124.26+255319.5, index 2111...
# Working on dwarf G 259-20B, index 2113...
# Working on dwarf 2MASSI J1743348+584411, index 2114...
# Working on dwarf WISEA J174336.62+154901.3, index 2115...
# Working on dwarf 2MASSW J1743415+212707, index 2116...
# Working on dwarf DENIS-P J1745346-164053, index 2117...
# Working on dwarf 2MASSW J1750129+442404, index 2120...
# Working on dwarf 2MASS J17502484-0016151, index 2122...
# Working on dwarf 2MASS J17534518-6559559, index 2124...
# Working on dwarf 2MASS J17561080+2815238, index 2127...
# Working on dwarf DENIS-P J175629.6-451822, index 2128...
# Working on dwarf DENIS-P J1756561-480509, index 2129...
# Working on dwarf LP 44-162, index 2130...
# Working on dwarf SDSS J175805.46+463311.9, index 2131...
# Working on dwarf 2MASSI J1807159+501531, index 2135...
# Working on dwarf WISEPA J181210.85+272144.3, index 2139...
# Working on dwarf LTT 7251B, index 2142...
# Working on dwarf 2MASS J18212815+1414010, index 2143...
# Working on dwarf LSR J1826+3014, index 2144...
# Working on dwarf 2MASS J18283572-4849046, index 2147...
# Working on dwarf 2MASS J18284076+1229207, index 2148...
# Working on dwarf 2MASSI J1835379+325954, index 2149...
# Working on dwarf LP 335-12, index 2150...
# Working on dwarf LP 44-334, index 2151...
# Working on dwarf 2MASSW J1841086+311727, index 2152...
# Working on dwarf CE 507, index 2153...
# Working on dwarf LHS 3406, index 2154...
# Working on dwarf SCR J1845-6357, index 2155...
# Working on dwarf 2MASS J18451889+3853248, index 2156...
# Working on dwarf 2MASS J18462188-5706040, index 2157...
# Working on dwarf 2MASSI J1847034+552243, index 2158...
# Working on dwarf LHS 3421B, index 2161...
# Working on dwarf PZ Tel B, index 2162...
# Working on dwarf WISEP J190648.47+401106.8, index 2165...
# Working on dwarf vB 10, index 2167...
# Working on dwarf 2MASS J19170993+7755597, index 2168...
# Working on dwarf 2MASS J19223062+6610194, index 2170...
# Working on dwarf HR 7329B, index 2171...
# Working on dwarf GJ 758B, index 2172...
# Working on dwarf LSPM J1925+0938, index 2173...
# Working on dwarf 2MASS J19285196-4356256, index 2175...
# Working on dwarf SSSPM J1930-4311, index 2176...
# Working on dwarf 2MASS J19303829-1335083, index 2177...
# Working on dwarf PSO J292.9372-06.3469, index 2178...
# Working on dwarf 2MASS J19355595-2846343, index 2179...
# Working on dwarf 2MASS J19360187-5502322, index 2180...
# Working on dwarf 2MASS J19395435-5216468, index 2181...
# Working on dwarf WISEA J194128.98-342335.8, index 2182...
# Working on dwarf KOI-205b, index 2183...
# Working on dwarf WISE J195113.62-331116.7, index 2184...
# Working on dwarf WISEA J195311.04-022954.7, index 2185...
# Working on dwarf GJ 1245B, index 2186...
# Working on dwarf 2MASS J19561542-1754252, index 2188...
# Working on dwarf 2MASS J20004841-7523070, index 2190...
# Working on dwarf 2MASS J20025265-1316418, index 2193...
# Working on dwarf WISE J200403.17-263751.7, index 2194...
# Working on dwarf HR 7672B, index 2195...
# Working on dwarf 2MASSI J2004536-141622, index 2196...
# Working on dwarf WISEA J200907.88-170448.0, index 2199...
# Working on dwarf LSPM J2010+0632B, index 2200...
# Working on dwarf 2MASS J20115649-6201127, index 2201...
# Working on dwarf DENIS J2013108-124244, index 2202...
# Working on dwarf 2MASS J20135152-2806020, index 2203...
# Working on dwarf 2MASS J20140359-2016217, index 2204...
# Working on dwarf WISEPC J201546.27+664645.1, index 2206...
# Working on dwarf WISE J201748.72-342102.5, index 2207...
# Working on dwarf WISEPA J201824.96-742325.9, index 2208...
# Working on dwarf 2MASS J20192695-2502441, index 2210...
# Working on dwarf LEHPM 2-0783, index 2211...
# Working on dwarf 2MASS J20232858-5946519, index 2212...
# Working on dwarf 2MASS J20261584-2943124, index 2213...
# Working on dwarf 2MASS J20282203-5637024, index 2215...
# Working on dwarf 2MASS J20334670-3733443, index 2217...
# Working on dwarf 2MASS J20343769+0827009, index 2218...
# Working on dwarf zeta Del B, index 2219...
# Working on dwarf 2MASS J20360316+1051295, index 2220...
# Working on dwarf LSR J2036+5059, index 2221...
# Working on dwarf WISEA J203644.55-084715.1, index 2222...
# Working on dwarf 2MASS J20370715-1137569, index 2223...
# Working on dwarf WISEA J203751.31-421645.2, index 2224...
# Working on dwarf 2MASS J20391314-1126531, index 2225...
# Working on dwarf LHS 3566, index 2226...
# Working on dwarf WISEA J204027.30+695924.1, index 2227...
# Working on dwarf 2MASS J20414283-3506442, index 2228...
# Working on dwarf WISEA J204218.13-082137.8, index 2229...
# Working on dwarf SDSS J204317.69-155103.4, index 2230...
# Working on dwarf Gl 802B, index 2231...
# Working on dwarf SIPS J2045-6332, index 2232...
# Working on dwarf 2MASS J20473176-0808201, index 2233...
# Working on dwarf SDSS J204749.61-071818.3, index 2234...
# Working on dwarf 2MASS J20482880-3255434, index 2236...
# Working on dwarf 2MASS J20484222-5127435, index 2237...
# Working on dwarf 2MASS J20491972-1944324, index 2238...
# Working on dwarf SDSS J205235.31-160929.8, index 2239...
# Working on dwarf 2MASS J20530910-0133039, index 2240...
# Working on dwarf 2MASSI J2057540-025230, index 2242...
# Working on dwarf 2MASSW J2101154+175658, index 2243...
# Working on dwarf 2MASS J21015233-2944050, index 2244...
# Working on dwarf WISE J210200.15-442919.5, index 2245...
# Working on dwarf 2MASSI J2104149-103736, index 2246...
# Working on dwarf 2MASS J21075409-4544064, index 2248...
# Working on dwarf chi Cap E, index 2249...
# Working on dwarf chi Cap F, index 2250...
# Working on dwarf PSO J318.4243+35.1277, index 2251...
# Working on dwarf PSO J318.5338-22.8603, index 2252...
# Working on dwarf WISEA J211543.59-322540.4, index 2253...
# Working on dwarf LP 397-10, index 2254...
# Working on dwarf WISEA J211807.07-321713.5, index 2256...
# Working on dwarf [HB88] M18, index 2257...
# Working on dwarf HD 203030B, index 2258...
# Working on dwarf WISEA J212354.78-365223.4, index 2260...
# Working on dwarf LSPM J2124+4003, index 2262...
# Working on dwarf [HB88] M19, index 2264...
# Working on dwarf [HB88] M20, index 2265...
# Working on dwarf SDSS J213154.43-011939.3, index 2267...
# Working on dwarf 2MASS J21321145+1341584, index 2268...
# Working on dwarf WISEPA J213456.73-713743.6, index 2271...
# Working on dwarf 2MASS J21371044+1450475, index 2272...
# Working on dwarf DENIS J2139136-352950, index 2274...
# Working on dwarf 2MASS J21392676+0220226, index 2275...
# Working on dwarf 2MASSW J2140293+162518, index 2276...
# Working on dwarf 2MASS J21403907+3655563, index 2277...
# Working on dwarf WISEA J214155.85-511853.1, index 2278...
# Working on dwarf HN Peg B, index 2279...
# Working on dwarf DENIS-P J2146.1-2153, index 2280...
# Working on dwarf Wolf 940B, index 2281...
# Working on dwarf 2MASSW J2147436+143131, index 2283...
# Working on dwarf 2MASS J21481326-6323265, index 2284...
# Working on dwarf 2MASS J21481628+4003593, index 2285...
# Working on dwarf SIMP J21483578+2239427, index 2286...
# Working on dwarf CFBDSIR J214947.2-040308.9, index 2287...
# Working on dwarf 2MASS J21495655+0603349, index 2288...
# Working on dwarf DENIS J2150133-661036, index 2289...
# Working on dwarf 2MASS J21501592-7520367, index 2290...
# Working on dwarf NLTT 52268B, index 2291...
# Working on dwarf 2MASS J21512797+3547206, index 2292...
# Working on dwarf 2MASS J21513839-4853542, index 2293...
# Working on dwarf LSPM J2153+1157B, index 2295...
# Working on dwarf 2MASS J21542494-1023022, index 2296...
# Working on dwarf SIMP J21543454-1055308, index 2297...
# Working on dwarf 2MASS J21544859-7459134, index 2298...
# Working on dwarf 2MASS J21572060+8340575, index 2299...
# Working on dwarf 2MASS J21574904-5534420, index 2300...
# Working on dwarf LSPM J2158+6117, index 2303...
# Working on dwarf WISE J215949.48-480854.9, index 2304...
# Working on dwarf DENIS-P J220002.05-303832.9, index 2305...
# Working on dwarf 2MASS J22021125-1109461, index 2307...
# Working on dwarf 2MASS J22025794-5605087, index 2308...
# Working on dwarf eps Indi B, index 2310...
# Working on dwarf 2MASSW J2206228-204705, index 2311...
# Working on dwarf 2MASSW J2206450-421721, index 2312...
# Working on dwarf 2MASSW J2208136+292121, index 2313...
# Working on dwarf GRH 2208-20, index 2317...
# Working on dwarf WISE J221140.52-475826.5, index 2318...
# Working on dwarf PM I22118-1005B, index 2319...
# Working on dwarf 2MASS J22114470+6856262, index 2320...
# Working on dwarf WISEA J221216.27-693121.6, index 2321...
# Working on dwarf 2MASS J22134491-2136079, index 2322...
# Working on dwarf 2MASSI J2214506-131959, index 2324...
# Working on dwarf 2MASS J22191486-6828018, index 2326...
# Working on dwarf WISEA J222013.75-361709.5, index 2327...
# Working on dwarf PHL 5038B, index 2328...
# Working on dwarf TVLM 890-60235, index 2331...
# Working on dwarf WISEA J222409.64-185242.1, index 2332...
# Working on dwarf 2MASSW J2224438-015852, index 2333...
# Working on dwarf WISEPC J222623.05+044003.9, index 2334...
# Working on dwarf 2MASS J22264440-7503425, index 2335...
# Working on dwarf 2MASS J22282889-4310262, index 2336...
# Working on dwarf LHS 523, index 2337...
# Working on dwarf WISE J223204.50-573010.5, index 2338...
# Working on dwarf 2MASS J22344161+4041387, index 2340...
# Working on dwarf 2MASS J22351658-3844154, index 2341...
# Working on dwarf 2MASS J22353560-5906306, index 2342...
# Working on dwarf LP 460-44, index 2343...
# Working on dwarf SDSS J223550.14+122737.3, index 2344...
# Working on dwarf G 216-7B, index 2348...
# Working on dwarf 2MASSI J2238074+435317, index 2349...
# Working on dwarf ULAS J223955.76+003252.6, index 2351...
# Working on dwarf 2MASS J22400144+0532162, index 2352...
# Working on dwarf WISEA J224128.33+043459.3, index 2353...
# Working on dwarf 2MASS J22425317+2542573, index 2354...
# Working on dwarf 2MASS J22431696-5932206, index 2355...
# Working on dwarf 2MASSW J2244316+204343, index 2356...
# Working on dwarf 2MASS J22444905-3045535, index 2357...
# Working on dwarf HIP 112422B, index 2359...
# Working on dwarf SDSSp J224953.45+004404.2, index 2361...
# Working on dwarf ULAS J225016.39+080822.4, index 2362...
# Working on dwarf 2MASSI J2252014-181558, index 2363...
# Working on dwarf DENIS-P J225210.73-173013.4, index 2364...
# Working on dwarf 2MASSI J2254188+312349, index 2365...
# Working on dwarf NLTT 55219B, index 2366...
# Working on dwarf 2MASSI J2254519-284025, index 2367...
# Working on dwarf SDSSp J225529.09-003433.4, index 2369...
# Working on dwarf WISE J230228.68-713441.6, index 2372...
# Working on dwarf 2MASS J23062928-0502285, index 2376...
# Working on dwarf SSSPM J2307-5009, index 2377...
# Working on dwarf 2MASS J23072655+8753294, index 2378...
# Working on dwarf DENIS J2308113-272200, index 2379...
# Working on dwarf WISE J231921.92+764544.4, index 2384...
# Working on dwarf 2MASS J2320292+412341, index 2386...
# Working on dwarf 2MASS J23211254-1326282, index 2388...
# Working on dwarf WISEA J232219.45-140726.2, index 2390...
# Working on dwarf 2MASS J23224684-3133231, index 2391...
# Working on dwarf 2MASS J23225299-6151275, index 2392...
# Working on dwarf 2MASS J23231347-0244360, index 2394...
# Working on dwarf 2MASS J23245065-5817554, index 2395...
# Working on dwarf WISEPC J232519.54-410534.9, index 2396...
# Working on dwarf PSO J351.3434-11.3514, index 2397...
# Working on dwarf HIP 115819B, index 2401...
# Working on dwarf DENIS J2329343-540858, index 2402...
# Working on dwarf APMPM J2330-4737, index 2403...
# Working on dwarf 2MASS J23302258-0347189, index 2404...
# Working on dwarf 2MASSI J2331016-040619, index 2405...
# Working on dwarf LSPM J2331+4607N, index 2406...
# Working on dwarf APMPM J2331-2750, index 2407...
# Working on dwarf SDSS J233129.35+155222.5, index 2408...
# Working on dwarf HD 221356D, index 2409...
# Working on dwarf SDSS J233358.42+005012.1, index 2411...
# Working on dwarf 2MASS J23343945+1933041, index 2413...
# Working on dwarf SDSS J233526.42+081721.3, index 2414...
# Working on dwarf WISE J233527.07+451140.9, index 2415...
# Working on dwarf 2MASS J23355015-3401477, index 2417...
# Working on dwarf 2MASS J23360735-3541489, index 2418...
# Working on dwarf 2MASS J23364395+2153388, index 2419...
# Working on dwarf 2MASS J23371491-0838084, index 2420...
# Working on dwarf kappa And B, index 2424...
# Working on dwarf WISEPC J234026.62-074507.2, index 2425...
# Working on dwarf Ross 248, index 2426...
# Working on dwarf APMPM J2344-2906, index 2428...
# Working on dwarf 2MASS J23453903+0055137, index 2432...
# Working on dwarf SIPS J2346-5928, index 2433...
# Working on dwarf 2MASS J23464599+1129094, index 2434...
# Working on dwarf APMPM J2347-3154, index 2435...
# Working on dwarf 2MASSW J2347368+270206, index 2436...
# Working on dwarf WISE J234755.42+683319.4, index 2437...
# Working on dwarf 2MASS J23494899+1224386, index 2440...
# Working on dwarf 2MASS J23512200+3010540, index 2442...
# Working on dwarf 1RXS J235133.3+312720 B, index 2443...
# Working on dwarf 2MASS J23515044-2537367, index 2444...
# Working on dwarf 2MASS J23520507-1100435, index 2445...
# Working on dwarf 2MASS J23532556-1844402, index 2446...
# Working on dwarf 2MASS J23535946-0833311, index 2447...
# Working on dwarf LHS 4039C, index 2449...
# Working on dwarf PSO J358.5527+22.1393, index 2450...
# Working on dwarf SSSPM J2356-3426, index 2452...
# Working on dwarf 2MASSI J2356547-155310, index 2453...
# Working on dwarf APMPM J2359-6246, index 2455...
# Working on dwarf WISEP J235941.07-733504.8, index 2456...
# Working on dwarf SSSPM J2400-2008, index 2457...

# %%
# reformat all_events
event_objects, event_sep, event_deltam = list(), list(), list()
for index, row in all_events.iterrows():
    # grab item 
    event_objects.append(row.object_name.item())
    
    # sep and delta_m
    if type(row.sep) is np.ndarray:
        event_sep.append(row.sep[0])
        event_deltam.append(row.delta_m[0])
    else:
        event_sep.append(row.sep)
        event_deltam.append(row.delta_m) 
        
all_events['object_name'] = event_objects
all_events['sep'] = event_sep
all_events['delta_m'] = event_deltam

# %%
all_events.sort_values(by=['delta_m'], ascending=True)
# Out:
#                   object_name        sep     delta_m       bd_ra     bd_dec  \
# 0                     L 726-8   0.061806    4.297247    24.77106 -17.948393
# 0   WISEA J030601.66-033059.0   0.004497    4.701461   46.507697  -3.519314
# 0      2MASSI J1807159+501531   0.042566   16.022464  271.816561  50.258207
# 0    WISE J041358.14-475039.3   0.068709   34.856879   63.493264 -47.842451
# 0     2MASS J05441150-2433018   0.072282   38.340655   86.049254 -24.554795
# 0                  LEHPM 3396   0.198856   46.036767   53.589044 -49.887463
# 2                     L 726-8   0.680972   47.346667   24.780187 -17.947024
# 0    WISE J222219.93+302601.4   0.052755   49.162770  335.583255  30.434634
# 0    SDSS J091659.09+512450.4   0.042377   51.171255  139.246517  51.414014
# 0      2MASSI J1743348+584411   0.073973   63.420977  265.895291  58.736249
# 4    WISE J085510.83-071442.5   1.141622   66.886383  133.771853  -7.243169
# 1                     L 726-8   1.064362   74.003020   24.770724 -17.948401
# 0    SDSS J233358.42+005012.1   0.057626   75.237345  353.494471   0.836981
# 0      2MASSI J0428510-225323   0.133903   90.872472   67.212917 -22.888915
# 0    SDSS J111316.95-000246.6   0.080945   90.915096  168.320661  -0.046378
# 0      2MASSI J1426316+155701   0.123118   94.526883  216.632071  15.950079
# 0                 HIP 112422B   0.059807  100.540223  341.577844  33.325189
# 0   WISEA J001450.17-083823.4   0.115105  146.998964    3.712387  -8.640346
# 0      2MASSW J0228110+253738   0.161810  150.791648   37.047413  25.627115
# 0      2MASSW J1411175+393636   0.197548  172.824301  212.817289  39.610642
# 0    SDSS J161928.31+005011.9   0.244691  176.290794  244.868341   0.836175
# 0     2MASS J12172935+0035326   0.247359  188.901789  184.372536   0.592394
# 2    WISE J085510.83-071442.5   3.236755  189.637893  133.758207  -7.242047
# 0          DENIS-P J1159+0057   0.395589  299.257871  179.910556   0.957425
# 0  WISEPC J131106.24+012252.4   0.802101  299.861212  197.778064   1.375281
# 0    SDSS J202820.32+005226.5   0.395360  331.233582   307.08552   0.874025
# 0    WISE J220905.73+271143.9   2.134698  339.551944  332.278578  27.190787
# 0    WISE J004945.61+215120.0   2.248162  411.851209   12.438431  21.855246
# 0              LSR J1826+3014   1.628563  465.416555  276.526556  30.233578
# 0  9906620767799062   42.548994  -1.858431  19.659395  2020.841889
# 0  9906620884582946  128.019097  -1.476632  23.408766  2018.580424
# 5  9906618721044696  133.782212  -7.241134  21.301928   2016.31896
# 0  9906631176290876   31.608013   26.67304  23.162975   2022.77755
# 0  9906620663860736    6.102311  -1.971606  20.697004  2019.232033
# 0  9906622030285305  178.642061   1.598329  21.540857  2015.724846
# 1  9906618721044243  133.761724  -7.246143  23.277842  2025.115674
# 3  9906618721044632  133.778633  -7.247552   23.40237  2017.526352
# 0  9906621733998406  128.411338   0.865107  22.417908  2023.812457
# 0  9906611508740328    6.183681   -27.1361  23.868223       2014.0
#
#         gaia_id
# 0           NaN
# 0           NaN
# 0           NaN
# 0           NaN
# 0  2.915188e+18
# 0  4.832732e+18
# 2           NaN
# 0  1.894730e+18
# 0           NaN
# 0           NaN
# 4           NaN
# 1           NaN
# 0  2.646165e+18
# 0           NaN
# 0  3.804049e+18
# 0           NaN
# 0           NaN
# 0           NaN
# 0  1.031835e+17
# 0           NaN
# 0  4.408577e+18
# 0  3.698498e+18
# 2  5.756957e+18
# 0  3.891238e+18
# 0  3.690955e+18
# 0  4.230729e+18
# 0  1.892434e+18
# 0  2.802121e+18
# 0           NaN
# 0  3.266938e+18
# 0  5.756957e+18
# 0  1.454551e+15
# 0  2.497289e+18
# 0  3.073123e+18
# 5  5.756957e+18
# 0           NaN
# 0  2.541757e+18
# 0  3.892263e+18
# 1           NaN
# 3           NaN
# 0  3.078514e+18
# 0           NaN

# %% [markdown]
# Now let's take the objects with events and perform MCs on them (sample 500 times):
#
# - There is one thing to note. I am checking that there is an event before the MC is run. This might initially seem silly considering I have already selected objects with a mass uncertainty < 1000 Mjup. A check might look redundant at first. But because I know the time of minimum separation, I am also changing the brown dwarf path to near that time. In doing so, I am recomputing the Horizons ephemerides using their module. The way the ephemerides are calculated, the vector output changes ever so slightly depending on the start time (which is different than the initial computation). This change of vector output slightly changes the eventual mass uncertaintly, and for objects with initially computed mass uncertainties near 1000 Mjup may be pushed over that limit. Therefore, I have to do this check beforehand, because I have a different start time (which will save time). And it's not like a mass uncertainty of 1000 Mjup is particularly helpful for these low mass objects anyways...

# %%
# make subset of dataframe with event object_names
event_rows = pd.DataFrame(all_obj.loc[all_obj['object_name'].isin(event_objects)])

mc_results = dict()
# iterate through all_events
for index, row in all_events.iterrows():
    print('Working on {}'.format(row.object_name))
    
    # find row of object in all_obj
    obj_row = pd.DataFrame(all_obj.loc[all_obj.object_name == row.object_name])
    
    # convert row to pd dataframe
    event_row = pd.DataFrame(row).T

    #print('obj row similarity', obj_row.object_name.item() == event_row.object_name.item())

    # brown dwarf observe date to create BrownDwarf instance
    t = time_to_good(obj_row.t0.item())

    # cater start and end of brown dwarf path to the event time (+- 0.1 years)
    t_min = round(float(event_row.time_of_min.item()), 2)

    t_start, t_end = time_to_good(t_min - 1, 'decimalyear'), time_to_good(t_min + 1, 'decimalyear')

    # instantiate BrownDwarf
    bd = BrownDwarf(obj_row, observ_date=t)
    bd_path = bd.find_path(start=t_start, end=t_end, step='6h')
    
    # find the background stars from the Legacy Survey
    stars = Fields(bd=bd)

    # find events with "new" object
    events = FindEvents(bd, stars, 1000)
    
    # perform the MC with 1000 samples and varying everything
    if len(events.event_table) > 0:
        mass_unc_list, sep_list, time_list, index_list = events.event_mcmc(samples=500, vary=['bd_ra', 'bd_dec', 'pi', 'mu_alpha', 'mu_delta'], prints=100)

        # add mass unc to dict
        mc_results[obj_row.object_name.item()] = mass_unc_list, sep_list, time_list, index_list
# Out:
# Working on WISE J004945.61+215120.0
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J041358.14-475039.3
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J083337.83+005214.2
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J085510.83-071442.5
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J085510.83-071442.5
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J085510.83-071442.5
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J085510.83-071442.5
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J085510.83-071442.5
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J085510.83-071442.5
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J220905.73+271143.9
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASSW J0228110+253738
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASSW J0832045-012835
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on DENIS-P J1159+0057
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASSW J1411175+393636
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on SDSS J161928.31+005011.9
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on SDSS J202820.32+005226.5
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J222219.93+302601.4
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISEA J001450.17-083823.4
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on BRI 0021-0214
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on LHS 1070
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on HIP 6217C
# Working on L 726-8
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on L 726-8
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on L 726-8
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASS J01423153+0523285
# Working on WISEPA J020625.26+264023.6
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on TVLM 831-154910
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on TVLM 831-161058
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on TVLM 831-165166
# Working on PSO J043.5395+02.3995
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISEA J030601.66-033059.0
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASS J03111547+0106307
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on LEHPM 3396
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASSI J0428510-225323
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on LEHPM 2-59
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on 2MASS J05441150-2433018
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on SDSS J091659.09+512450.4
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on SDSS J111316.95-000246.6
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASS J11543399+0135545
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASS J12172935+0035326
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISEPC J131106.24+012252.4
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASSI J1426316+155701
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on SDSS J163355.23+010027.0
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASSI J1743348+584411
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on 2MASSI J1807159+501531
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on LSR J1826+3014
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on WISE J215949.48-480854.9
# Working on HIP 112422B
# Working on sample #0...
# Working on sample #100...
# Working on sample #200...
# Working on sample #300...
# Working on sample #400...
# Working on HIP 115819B
# Working on SDSS J233358.42+005012.1
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/judahluberto/opt/anaconda3/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),

# %% [markdown]
# Convert sep_list in mc_results to mas (1000x currently have):

# %%
for i in mc_results:
    # make a list
    mc_results[i] = list(mc_results[i])
    
    # reassign
    mc_results[i][1] = np.array(mc_results[i][1]) * 1000

# %% [markdown]
# I also should convert the separations from arcseconds to milliarcseconds:

# %% [markdown]
# Now to save mc_results so I don't have to run this again in the future. I was thinking about good ways to do it, like np.savez etc. etc., but because I don't have too many objects to save, I'm going to save each object into their own individual file using savez:

# %%
for i in mc_results:
    print('Saving {}'.format(i))
    
    # get data
    deltam = mc_results[i][0]
    sep = mc_results[i][1]
    time = mc_results[i][2]
    index = mc_results[i][3]
    
    # file name and path
    filename = os.path.join('/Users/judahluberto/object_massuncertainty', i)
    
    np.savez(filename, deltam=deltam, sep=sep, time=time, index=index)
# Out:
# Saving WISE J004945.61+215120.0
# Saving WISE J041358.14-475039.3
# Saving WISE J083337.83+005214.2
# Saving WISE J085510.83-071442.5
# Saving WISE J220905.73+271143.9
# Saving 2MASSW J0228110+253738
# Saving 2MASSW J0832045-012835
# Saving 2MASSW J1411175+393636
# Saving SDSS J202820.32+005226.5
# Saving WISE J222219.93+302601.4
# Saving WISEA J001450.17-083823.4
# Saving LHS 1070
# Saving L 726-8
# Saving WISEPA J020625.26+264023.6
# Saving TVLM 831-161058
# Saving PSO J043.5395+02.3995
# Saving WISEA J030601.66-033059.0
# Saving LEHPM 3396
# Saving 2MASSI J0428510-225323
# Saving 2MASS J05441150-2433018
# Saving SDSS J091659.09+512450.4
# Saving WISEPC J131106.24+012252.4
# Saving 2MASSI J1426316+155701
# Saving 2MASSI J1743348+584411
# Saving 2MASSI J1807159+501531
# Saving LSR J1826+3014
# Saving HIP 112422B

# %% [markdown]
# Checking the first file (alphabetically) to see if saved correctly:

# %%
object_saved = np.load('/Users/judahluberto/object_massuncertainty/2MASSW J0228110+253738.npz')

object_saved['deltam']
# Out:
# array([136.48622555, 143.01641821, 151.04655332, 170.58780467,
#        151.26242902, 144.95362151, 149.22767923, 131.21601071,
#        151.5709125 , 171.67056153, 146.79820363, 133.29494339,
#        157.28934853, 149.73701905, 147.9396125 , 149.12016615,
#        162.30136174, 154.52552911, 159.20016408, 150.59770581,
#        132.54405677, 149.33382826, 157.47815605, 152.79783904,
#        152.62746748, 166.64278747, 157.71061725, 161.39384574,
#        129.48487553, 141.55770114, 153.06655616, 150.49888237,
#        151.98128762, 155.76589637, 164.11361164, 153.14538613,
#        174.51246372, 156.00363552, 157.75393272, 168.23711236,
#        156.99350473, 142.27542219, 154.72798902, 140.97595409,
#        151.3510447 , 157.59319939, 154.94398703, 139.233917  ,
#        139.8278428 , 179.14561934, 141.94849476, 147.97761782,
#        157.66645647, 147.06890731, 145.21548894, 149.26460125,
#        162.24773018, 150.11925359, 155.93777095, 165.14181104,
#        156.48823578, 147.22783664, 150.19801631, 156.08865104,
#        156.82975142, 145.92036751, 136.50897962, 161.25537419,
#        137.80833072, 131.31130244, 157.98267556, 151.15822344,
#        157.41926377, 149.32034111, 139.31450899, 126.672319  ,
#        152.29804484, 135.72221164, 162.94640661, 145.11178059,
#        147.65389705, 145.44241313, 160.98200803, 145.83341271,
#        157.79199018, 149.15478436, 157.69009793, 135.61036415,
#        165.62840666, 166.95632466, 151.10805357, 134.7614128 ,
#        158.12511661, 140.66996044, 150.38344828, 161.06795703,
#        164.97015144, 163.10316928, 163.50301767, 156.57033551,
#        158.34933243, 148.39572324, 155.81584068, 152.84065499,
#        137.50449129, 142.44708505, 153.19602432, 148.6409925 ,
#        145.42094204, 156.01517552, 150.47676588, 146.79712527,
#        151.84954367, 149.32761685, 155.43907924, 151.19886111,
#        156.76480872, 156.7641454 , 172.66847189, 156.63854205,
#        156.78785072, 146.74660712, 144.47113146, 147.87256525,
#        157.84094998, 143.0331311 , 158.13275696, 158.20812711,
#        146.25685771, 163.68273518, 154.71015549, 144.60704652,
#        143.84448652, 153.35598033, 158.53844138, 154.65168145,
#        134.19707019, 162.62037159, 154.72634619, 138.49937076,
#        146.44212995, 168.90334985, 155.38125676, 149.69596328,
#        141.16925443, 162.03420883, 135.84205427, 157.3569918 ,
#        156.80974288, 159.23690736, 155.48311009, 161.56734603,
#        170.04217994, 156.84957594, 158.12632378, 149.66265739,
#        152.43921466, 141.14910932, 166.8580861 , 153.89855007,
#        140.3118025 , 147.48720986, 141.7449498 , 154.63578092,
#        153.2408138 , 130.20671082, 140.20189913, 140.87788984,
#        165.38725304, 147.76509537, 151.56293737, 143.21883075,
#        153.32698983, 157.07673406, 152.9107766 , 150.31511663,
#        158.28933906, 160.01465331, 161.1710469 , 163.79572804,
#        159.00637512, 150.14893711, 157.04862038, 159.95388737])

# %% [markdown]
# Import all the files and their data (so I don't have to redo the code that takes so long):

# %%
directory = '/Users/judahluberto/object_massuncertainty'

#mc_results = dict()
for file in os.listdir(directory):
    # ignore the DS_Store file
    if file.startswith('.DS_Store'):
        continue
        
    if file[:-4] not in list(all_obj.object_name):
        continue
    
    # do real work
    filename = os.path.join(directory, file)
    data = np.load(filename)
    
    # add to mc_results and change sep to mas
    #mc_results[file[:-4]] = data['deltam'], np.array(data['sep']) * 1000

# %% [markdown]
# #### I need to put this data of the objects into an ApJ accepted file format:

# %% [markdown]
# Create a pandas dataframe of the table I want to format:

# %%
# prepare all_the_bds to be put into a table -- organize by ra, dec later because mc_results depends on this order
obj_table = all_obj.copy()

obj_table = obj_table.drop(['t0', 'pi', 'mu_alpha', 'mu_delta', 'pm_ra', 'pm_dec', 'pm_mu_alpha', 'pm_mu_delta', 'pm_pi'], axis=1)

# %% [markdown]
# Add necessary data to this table:
#
# - It's kind of ugly code because have to append to lots of lists, and then add those lists to the dataframe. I could make it cleaner and more beautiful...

# %%
# create duplicate array of all_events to only grab the lowest Mjup event
all_events_by_mjup = all_events.sort_values(by=['delta_m'], ascending=True)

# lists that will append
min_times, mags, seps, seps_e, delt_ms, delt_ms_e, times, times_e, gaia_sources = list(), list(), list(), list(), list(), list(), list(), list(), list()
for i in obj_table['object_name']:
    # if one of the objects with the events, add data
    if i in mc_results.keys() and i != 'SDSS J163355.23+010027.0':        
        # find index of where at in all_events
        index = list(all_events_by_mjup.object_name).index(i)
        
        # grab data from all_events
        #min_time = round(list(all_events_by_mjup['time_of_min'])[index], 2)
        mag = round(list(all_events_by_mjup['mag'])[index], 2)
        
        # calc data from MC
        delt_m, delt_m_e = np.mean(mc_results[i][0]), np.std(mc_results[i][0])
        sep, sep_e = np.mean(mc_results[i][1]), np.std(mc_results[i][1])
        time, time_e = np.mean(mc_results[i][2]), np.std(mc_results[i][2])

        # round calculated data
        sep, sep_e = round(sep, 2), round(sep_e, 2)
        delt_m, delt_m_e = round(delt_m, 2), round(delt_m_e, 2)
        time, time_e = round(time, 4), round(time_e, 4)
        
        # gaia id
        gaia_id = list(all_events_by_mjup['gaia_id'])[index]
        
        if ~np.isnan(gaia_id):
            gaia_source = True
            
        else:
            gaia_source = False
        
    # if not an object with an event, add "-"
    else:
        min_time, mag, sep, sep_e, delt_m, delt_m_e, time, time_e, gaia_source = '-', '-', '-', '-', '-', '-', '-', '-', '-'
        
    min_times.append(min_time)
    mags.append(mag)
    seps.append(sep)
    seps_e.append(sep_e)
    delt_ms.append(delt_m)
    delt_ms_e.append(delt_m_e)
    times.append(time)
    times_e.append(time_e)
    gaia_sources.append(gaia_source)
    
# add to df
#obj_table['t_min'] = min_times
obj_table['Mag_bs'] = mags

obj_table['Sep_min'] = seps
obj_table['Sep_min_e'] = seps_e
obj_table['Delta_m'] = delt_ms
obj_table['Delta_m_e'] = delt_ms_e

obj_table['t_min'] = times
obj_table['t_min_e'] = times_e

obj_table['Gaia_Source'] = gaia_sources

# now rearrange by ra, dec
obj_table = obj_table.sort_values('ra')

# %% [markdown]
# Add J-band (MKO system) photometry for the brown dwarfs):

# %%
k21_jmko_file = 'apjsabd107t17_mrt.txt'
b20_jmko_file = 'ajab84f4t1_mrt.txt'

ucs_jmko = ucs_obj_all[['J_MKO', 'Jerr_MKO', 'object_name']]

# open files
k21_jmko = pd.DataFrame(np.array(ascii.read(k21_jmko_file)))
b20_jmko = pd.DataFrame(np.array(ascii.read(b20_jmko_file)))

# get only column want
k21_jmko = k21_jmko[['JMKO', 'JMKe', 'FName']]
b20_jmko = b20_jmko[['Object', 'Jmag', 'e_Jmag']]

# rename columns
k21_jmko = k21_jmko.rename(columns = {'JMKe': 'JMKO_e', 'FName': 'object_name'})
b20_jmko = b20_jmko.rename(columns = {'Jmag': 'JMKO', 'e_Jmag': 'JMKO_e', 'Object': 'object_name'})
ucs_jmko = ucs_jmko.rename(columns = {'J_MKO': 'JMKO', 'Jerr_MKO': 'JMKO_e'})

# create list of all the magnitudes
jmko, jmko_e = list(), list()
for index, row in obj_table.iterrows():
    # find where from
    ref = row.Ref
    obj = row.object_name

    # locate row in J_MKO tables
    if ref == 'K21':
        obj_row = pd.DataFrame(k21_jmko.loc[k21_jmko.object_name == obj])

    if ref == 'B20':
        obj_row = pd.DataFrame(b20_jmko.loc[b20_jmko.object_name == obj])
        
    if ref == 'UCS':
        obj_row = pd.DataFrame(ucs_jmko.loc[ucs_jmko.object_name == obj])
        
    # some objects with astrometry in don't have a magnitude, append np.nan
    if len(obj_row) == 0:
        jmko.append(np.nan)
        jmko_e.append(np.nan)

        continue
             
    jmko.append(round(obj_row.JMKO.item(), 2))
    jmko_e.append(round(obj_row.JMKO_e.item(), 2))
            
# add columns to obj_table
obj_table['JMKO'] = jmko
obj_table['JMKO_e'] = jmko_e

# replace NaN with '-'
obj_table = obj_table.fillna('-')

# %%
# reorder columns
cols = ['object_name', 'Ref', 'ra', 'dec', 'JMKO', 'JMKO_e', 'Mag_bs', 't_min', 't_min_e', 'Sep_min', 'Sep_min_e', 'Delta_m', 'Delta_m_e', 'Gaia_Source']

obj_table = obj_table[cols]

# rename Mag
#obj_table = obj_table.rename(columns = {'Mag_BS': 'Mag_bs'})

# %%
obj_table[obj_table.t_min_e != '-']
# Out:
#                      object_name  Ref          ra        dec   JMKO JMKO_e  \
# 683    WISEA J001450.17-083823.4  UCS    3.713295  -8.640502  14.43   0.03
#byte_descriptions = ' 1- 28 A28   ---     ObN      Name of Object \n 30- 42 A13.  ---     Ref.      Reference Source of Brown Dwarf \n 44- 50 F6.2   yrs     t_min      Date of Minimum Separation (- if no event) \n 52- 56 F4.2   ---     Mag.      Magnitude of Background Star (- if no event) \n 57- 61 F4.2   mas     Sep.      Minimum Separation of Brown Dwarf and Background Star \n 63- 68 F5.2   Mjup     Delta_M      Predicted Mass Uncertainty'

byte_descriptions =   """  1- 28 A28    ---     ObN           Name of Object 
 30- 42 A13.   ---     Ref           Reference Source of Object
 44- 48 F4.2   mag     JMKO          Object magnitude in MKO J-band
 50- 52 F3.2   mag     JMKO_e        Error in Object magnitude
 54- 58 F4.2   mag     Mag_bs        Magnitude of Background Star (- if no event) 
 60- 66 F6.2   yrs     t_min         Date of Minimum Separation (- if no event) 
 69- 73 F4.2   mas     Sep           Minimum Separation of Object and Background Star 
 75- 79 F4.2   mas     Sep_e         Error in Minimum Separation
 81- 86 F5.2   Mjup    Delta_M       Predicted Mass Uncertainty
 88- 92 F4.2   Mjup    Delta_M_e     Error in Predicted Mass Uncertainty
 94- 97 I1     ---     Gaia_Source   If Background Source is in Gaia"""

beginning = top + ' \n' + double_lines + ' \n' + byte_by_byte + ' \n' + single_lines + ' \n' + headers + ' \n' + single_lines + ' \n' + byte_descriptions + ' \n' + single_lines + ' \n'

with open('browndwarfs.txt', 'a') as file:
    file.write(beginning)
    
    for index, row in obj_table.iterrows():
        # grab itemsb
        object_name = row['object_name']
        ref = row['Ref']
        t_min = row['t_min']
        t_min_e = row['t_min_e']
        mag = row['Mag_bs']
        sep_min = row['Sep_min']
        sep_min_e = row['Sep_min_e']
        delta_m = row['Delta_m']
        delta_m_e = row['Delta_m_e']
        jmko = row['JMKO']
        jmko_e = row['JMKO_e']
        gaia_source = row['Gaia_Source']

        # format as needed
        object_name = "{:<28}".format(object_name)
        ref = "{:>13}".format(ref)
        t_min = "{:>7}".format(str(t_min))
        mag = "{:>5}".format(str(mag))
        sep_min = "{:>5}".format(str(sep_min))
        sep_min_e = "{:>5}".format(str(sep_min_e))
        delta_m = "{:>6}".format(str(delta_m))
        delta_m_e = "{:>5}".format(str(delta_m_e))
        jmko = "{:>5}".format(str(jmko))
        jmko_e = "{:>4}".format(str(jmko_e))
        
        if gaia_source != '-':
            gaia_source = int(gaia_source)
            
        gaia_source = "{:>3}".format(str(gaia_source))

        item = object_name + ' ' + ref + ' ' + jmko + ' ' + jmko_e + ' ' + mag + ' ' + t_min + ' ' + sep_min + ' ' + sep_min_e + ' ' + delta_m + ' ' + delta_m_e + ' ' + gaia_source + " \n"

        file.write(item)

# %% [markdown]
# I also want to output this in a form I can put in my LaTeX table...

# %%
# format atb_with_results into latex table
obj_table_events = obj_table[obj_table.t_min != '-']

in_still = {i: i in list(all_obj.object_name) for i in list(all_events.object_name)}

for index, row in obj_table_events.iterrows():
    # reformat row to combine the values and errors
    row['Sep_min'] = str(row['Sep_min']) + '$\pm$' + str(row['Sep_min_e'])
    row['Delta_m'] = str(row['Delta_m']) + '$\pm$' + str(row['Delta_m_e'])
    row['t_min'] = str(row['t_min']) + '$\pm$' + str(row['t_min_e'])
    
    # JMKO needs to be specialized a little
    if row['JMKO'] == '-':
        row['JMKO'] = '-'
        
    else:
        row['JMKO'] = str(row['JMKO']) + '$\pm$' + str(row['JMKO_e'])

    row = row.drop(['Sep_min_e', 'Delta_m_e', 'ra', 'dec', 't_min_e', 'JMKO_e'])

    # create line
    line = ''
    for value in row:
        line += str(value) + ' & '

    line = line[:-3] + r' \\'

    print(line)
# Out:
# WISEA J001450.17-083823.4 & UCS & 14.43$\pm$0.03 & 21.55 & 2018.7386$\pm$0.0009 & 114.89$\pm$0.63 & 146.73$\pm$0.81 & False \\
# BRI 0021-0214 & UCS & 11.75$\pm$0.01 & 20.7 & 2018.3536$\pm$0.0011 & 410.37$\pm$0.86 & 131.99$\pm$0.28 & True \\
# LHS 1070 & UCS & 9.14$\pm$0.03 & 23.87 & 2013.0007$\pm$0.0 & 4687.73$\pm$2.59 & 865.55$\pm$0.48 & False \\
# WISE J004945.61+215120.0 & K21 & 16.36$\pm$0.02 & 19.99 & 2023.7871$\pm$0.0014 & 3010.16$\pm$7.88 & 551.44$\pm$1.44 & True \\
# L 726-8 & UCS & - & 14.96 & 2024.9474$\pm$0.0006 & 680.76$\pm$1.67 & 47.33$\pm$0.12 & False \\
# WISEPA J020625.26+264023.6 & UCS & 16.42$\pm$0.11 & 23.16 & 2022.7868$\pm$0.0025 & 1292.26$\pm$4.29 & 637.96$\pm$2.12 & False \\
# 2MASSW J0228110+253738 & B20 & 13.76$\pm$0.02 & 23.35 & 2018.4783$\pm$0.1091 & 161.64$\pm$10.44 & 150.63$\pm$9.73 & True \\
# TVLM 831-154910 & UCS & 12.86$\pm$0.03 & 19.66 & 2019.9145$\pm$0.0028 & 332.54$\pm$0.24 & 429.37$\pm$0.31 & True \\
# PSO J043.5395+02.3995 & UCS & 15.92$\pm$0.01 & 13.75 & 2025.3894$\pm$0.0005 & 3034.24$\pm$5.87 & 534.17$\pm$1.03 & True \\
# WISEA J030601.66-033059.0 & UCS & 14.4$\pm$0.03 & 19.9 & 2018.7305$\pm$0.0008 & 1.32$\pm$0.86 & 1.38$\pm$0.9 & False \\
# 2MASS J03111547+0106307 & UCS & - & 16.55 & 2021.0544$\pm$0.0003 & 378.18$\pm$0.1 & 164.31$\pm$0.04 & True \\
# LEHPM 3396 & UCS & 11.31$\pm$0.02 & 14.32 & 2027.1265$\pm$0.0008 & 1058.01$\pm$2.23 & 244.94$\pm$0.52 & True \\
# WISE J041358.14-475039.3 & K21 & 19.71$\pm$0.13 & 23.47 & 2031.8453$\pm$0.2811 & 63.16$\pm$29.1 & 32.04$\pm$14.76 & False \\
# 2MASSI J0428510-225323 & UCS & 13.47$\pm$0.02 & 22.48 & 2015.6787$\pm$0.0026 & 133.72$\pm$2.6 & 90.75$\pm$1.76 & False \\
# 2MASS J05441150-2433018 & UCS & 12.51$\pm$0.02 & 19.17 & 2021.5907$\pm$0.0002 & 18.61$\pm$0.16 & 9.87$\pm$0.08 & True \\
# 2MASSW J0832045-012835 & B20 & 14.08$\pm$0.02 & 23.41 & 2017.7333$\pm$0.2935 & 392.39$\pm$15.24 & 238.59$\pm$9.27 & True \\
